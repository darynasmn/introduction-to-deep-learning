# %% [markdown]
# # Cifar10 Classification

# %% [markdown]
# Until now, we have implemented several pieces of a deep learning pipeline and trained a two-layer neural network, but all hyperparameters were pre-set to values yielding resonable results. However, in real problems a large part of the work will be geared towards finding the best hyperparameter settings for a certain problem. In this notebook we will explore some good practices for network debugging and hyperparameters search, as well as extending our binary classification neural network to a multi-class one.
#
# Let's go!
#
# **Note 1**: This exercise is quite heavy with computations. We recommend using Google-Colab.
#
# **Note 2**: This exercise takes time, so start early!!

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# In mid August 2025, Google Colab officially moved to Python 3.12. This may cause compatibility issues with some of the course's exercises. Therefore, if running them in colab, revert to the runtime version of July 2025. To do this, go to Runtime >> Change runtime type >> Runtime version.
#
# Uncomment the following cell to mount your gdrive if you are using the notebook in google colab:

# %%
"""
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_06'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
"""

# %%
# Some lengthy setup.
import matplotlib.pyplot as plt
import numpy as np
import os
import urllib.request

from exercise_code.networks.layer import (
    Sigmoid, 
    Relu, 
    LeakyRelu, 
    Tanh,
)
from exercise_code.data import (
    DataLoader,
    ImageFolderDataset,
    MemoryImageFolderDataset,
    RescaleTransform,
    NormalizeTransform,
    FlattenTransform,
    ComposeTransform,
)
from exercise_code.data.image_folder_dataset import RandomHorizontalFlip
from exercise_code.networks import (
    ClassificationNet,
    BCE,
    CrossEntropyFromLogits
)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
os.environ['KMP_DUPLICATE_LIB_OK']='True' # To prevent the kernel from dying.

# %% [markdown]
# # 1. Quick recap (and some new things)

# %% [markdown]
# Until now, in the previous exercises, we focused on building and understanding all the necessary modules for training a simple model. We followed the Pytorch implementations closely, as this is the framework we will use later and we wanted you to have a smoother transition to its APIs.
#
# In the figure below you can see the main components in Pytorch. Let's start with a quick recap of **our implementation** of these components.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Everything is already implemented for this part, but we <b>strongly</b> encourage you to check  the respective source files in order to have a better understanding. </p>
# </div>

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/800/1*uZrS4KjAuSJQIJPgOiaJUg.png" style="width: 500px;">

# %% [markdown]
# ## 1.1 Dataset and Dataloader

# %% [markdown]
# Data preparation is an important part of deep learning projects. Because the data can come in different formats and from different sources, it must be prepared in a certain way, which depends on the application. One part, however, is uniform: since an entire dataset is usually too large to handle at once, we train our models on smaller batches of data.
#
# The goal of the ```Dataset``` class is to encapsulate all the 'dirty' data processing: loading and cleaning the data, storing features (or names of files where features can be found) and labels, as well as providing the means for accessing individual (transformed) items of the data using the ```__getitem__()``` function and an index. You already implemented an ```ImageFolderDataset``` (in ```exercise_code/data/image_folder_dataset.py```) class in Exercise 3. We we will reuse this class here.
#
# For processing the data, you implemented several transforms in Exercise 3 (```RescaleTransform```, ```NormalizeTransform```, ```ComposeTransform```). In this exercise we are working with images, which are multidimensional arrays, but we are using a simple feedforward neural network which takes an one dimensional array as an input, so it is necessary to reshape the images before feeding them into the model.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the reshape operation in the <code>FlattenTransform</code> class, which can be found in <code>../exercise_06/exercise_code/data/image_folder_dataset.py</code>. </p>
# </div>

# %%
download_url = "https://i2dl.vc.in.tum.de/static/data/cifar10.zip"
i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
cifar_root = os.path.join(i2dl_exercises_path, "datasets", "cifar10")

# %% [markdown]
# ## The usual memory vs local data warning
# If you are using google colab or store your files on a local HDD, iterating over dataset takes quite some time and blablabla. You know the drill by now ;).
#
# <div class="alert alert-danger">
#     <h3>Warning</h3>
#     <p>Loading the whole dataset into memory will not work if you are using a machine with 4GB of RAM or less (depending on your other programs such as memory hungry web browsers). Consider closing some open programs or simply use the local on-demand ImageFolderDataset.</p>
#     <p>In addition we want to warn you that everytime you execute a cell like "dataset2 = MemoryImageFolderDataset..." you are loading a 1.2GB matrix into your memory. If you do this often enough this notebook will crash on every machine. Therefore, we make sure to always use a single variable "dataset" which will be overwritten by future cells to avoid straining your memory too much.</p>
# </div>

# %%
# Choose your preferred dataset here

# DATASET = ImageFolderDataset
DATASET = MemoryImageFolderDataset

# %% [markdown]
# Now that this has been taken care of, back to the actual loading.

# %%
# Use the Cifar10 mean and standard deviation computed in Exercise 3.
cifar_mean = np.array([0.49191375, 0.48235852, 0.44673872])
cifar_std  = np.array([0.24706447, 0.24346213, 0.26147554])

# Define all the transforms we will apply on the images when 
# retrieving them.
rescale_transform = RescaleTransform()
normalize_transform = NormalizeTransform(
    mean=cifar_mean,
    std=cifar_std
)
flatten_transform = FlattenTransform()
compose_transform = ComposeTransform([rescale_transform, 
                                      normalize_transform,
                                      flatten_transform])

# Create a train, validation and test dataset.
datasets = {}
for mode in ['train', 'val', 'test']:
    crt_dataset = DATASET(
        mode=mode,
        root=cifar_root, 
        transform=compose_transform,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2}
    )
    datasets[mode] = crt_dataset
    print(len(crt_dataset))
# Out:
# 30000
# 10000
# 10000

# %% [markdown]
# Then, based on this ```Dataset``` object, we can construct a ```Dataloader``` object which samples a random mini-batch of data at once.

# %%
# Create a dataloader for each split.
dataloaders = {}
for mode in ['train', 'val', 'test']:
    crt_dataloader = DataLoader(
        dataset=datasets[mode],
        batch_size=256,
        shuffle=True,
        drop_last=True,
    )
    dataloaders[mode] = crt_dataloader

# %% [markdown]
# Because the ```Dataloader``` has the ```__iter__()``` method, we can simply iterate through the batches it produces, like this:
#
# ```python
# for batch in dataloader['train']:
#     do_something(batch)
# ```

# %% [markdown]
# ## 1.2 Data Augmentation
#
# After the preprocessing steps, our data is in a good shape and ready to be fed into our network. As explained in the chapter above, we used the transformation functions `RescaleTransform`, `NormalizeTransform` and `FlattenTransform` to achieve this shape. These are the general steps that you need to perform on the data before you can start training. Of course, all these steps have to be applied to our three dataset splits (train, val and test split). In other words, preprocessing involves preparing the data before it can be used for training and inference.
#
# Besides these basic transformations, there are many other transformation methods that you can apply to the images. For example, you can <b>flip the images horizontally</b> or <b>blur the images</b> and use these new images to enlarge the dataset. This idea is called Data Augmentation and it involves methods that alter the training images to generate a synthetic dataset that is larger than your original dataset. This will hopefully improve the performance of your model. There is one important difference between data augmentation and data preprocessing: The transformation methods used to enlarge your dataset should only be applied to the training data. The validation and test data should not be affected by these methods.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>The choice of transformation methods for data augmentation can be seen as a hyperparameter of your model. You can try to include these to enlarge your training data and obtain better results for your model. In <code>exercise_code/data/image_folder_dataset.py</code> we implemented the function <code>RandomHorizontalFlip</code> for you, which is randomly flipping an image horizontally. Check out the implementation.</p>
#     <p> Later, we will perform hyperparameter tuning. In order to improve your model's performance, you can include some other data augmentation methods. Feel free to play around and to implement other methods as for example Gaussian Blur or Rotation. </p>
# </div>
#
# Let us quickly check the `RandomHorizontalFlip` method with an image of the Cifar10 dataset in the following cell.

# %%
#Load the data in a dataset without any transformation 
dataset = DATASET(
        mode=mode,
        root=cifar_root, 
        download_url=download_url,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2},
    )

#Retrieve an image from the dataset and flip it
image = dataset[1]['image']
transform = RandomHorizontalFlip(1)
image_flipped = transform(image)

#Show the two images
plt.figure(figsize = (2,2))
plt.subplot(1, 2, 1)
plt.imshow(image.astype('uint8'))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(image_flipped.astype('uint8'))
plt.axis('off')
plt.title("Left: Original Image, Right: Flipped image")
plt.show()

# %% [markdown]
# ## 1.3 Layers
#
# Now, that the data is prepared, we can take a look at the model we are using. In our case it will be a neural network.
#
# In Exercise 5, you implemented a simple 2-layer neural network that had a hidden size as a parameter:
#
# $$
# {\hat{y}} = \sigma(\sigma({x W_1} + {b_1}) {W_2} + {b_2})
# $$
#
# where $ \sigma({x}) $ was the sigmoid function, $ {x} $ was the input, $ {W_1}, {W_2} $ the weight matrices and $ {b_1}, {b_2}$ the biases for the two layers.
#
# This is how we used this network:

# %%
input_size = datasets['train'][0]['image'].shape[0]
model = ClassificationNet(input_size=input_size, 
                          hidden_size=512)

# %% [markdown]
# Note that we updated the ```ClassificationNet``` from the previous exercise. Now you can customize the number of outputs, the choice of activation function, the hidden size etc. We encourage you to check the implementation in ```exercise_code/networks/classification_net.py```

# %%
num_layer = 2
reg = 1e-6

model = ClassificationNet(activation=Relu, 
                          num_layer=num_layer, 
                          reg=reg,
                          num_classes=10)

# %% [markdown]
# Performing the forward and backward passes through the model was quite simple:
#
# ```python
#
# # X is a batch of training features
# # X.shape = (batch_size, features_size)
# y_out = model.forward(X)
#
# # dout is the gradient of the loss function w.r.t the output of the network.
# # dout.shape = (batch_size, )
# model.backward(dout)
# ```

# %% [markdown]
# Just as the learning rate or the number of epochs we want to train for, the number of hidden layers and the number of units in each hidden layer are also hyperparameters that we can tune. In this notebook you can play with networks of different sizes to see the impact that the network capacity has.
#
# Before we move on to the loss functions, let's have a look at the activation functions. The choice of an activation function can have a huge impact on the performance of the network you are designing. So far, you have implemented the `Sigmoid` and the `Relu` activation functions in Exercise 5.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Take a look at the <code>Sigmoid</code> and the <code>Relu</code> class in <code>exercise_code/networks/layer.py</code> and the implementation of the respective forward and backward passes. Make sure to understand why we used <b>element-wise product</b> instead of dot product in the backward pass of the <code>Sigmoid</code> class to compute the gradient <code>dx</code>. That will be helpful for your later implementation of other activation functions.</p>
#     <p> <b>Note:</b> The <code>cache</code> variable is used to store information from the forward pass and then pass this information in the backward pass to make use of it there. The implementation of both classes shows that this variable can be used differently - depending on which information is needed in the backward pass. </p>
# </div>
#
# Now, we want to have a look at two other, very common activation functions that you have already seen in the lecture: Leaky ReLU activation function and Tanh activation function.
#
# **Leaky Relus** are one attempt to fix the “dying ReLU” problem. Instead of the function being zero when $ x < 0 $, a leaky ReLU has a small negative slope (for example, 0.01).  The function computes $f(x) = \mathbb{1}(x < 0) (\alpha x) + \mathbb{1}(x>=0) (x)$ where $\alpha$ is a small constant. Some people report success with this form of activation function, but the results are not always consistent.
#
# The **tanh non-linearity** squashes a real-valued number into the range [-1, 1]. Like the sigmoid neuron, its activations saturate, but unlike the sigmoid neuron its output is zero-centered. Therefore, in practice the tanh non-linearity is always preferred to the sigmoid non-linearity. Also note that the tanh neuron is simply a scaled sigmoid neuron, in particular the following holds: $\tanh(x) = 2 \cdot \sigma(2x) -1$.
#
# <img class=left src=https://pytorch.org/docs/stable/_images/LeakyReLU.png alt="Figure3" width="350" align='left'/>
# <img class=right src=https://pytorch.org/docs/stable/_images/Tanh.png alt="Figure4" width="350"/>
#
# <div class="alert alert-info">
#     <h3>Task: Implement Activation Layers</h3>
#     <p> Now, it is your turn to implement the <code>LeakyRelu</code> and the <code>Tanh</code> class in <code>exercise_code/networks/layer.py</code> by completing the <code>forward</code> and the <code>backward</code> functions. You can test your implementation in the following two cells. </p>
#     <p> <b>Note:</b> Always remember to return a cache in <code>forward</code> for later backpropagation in <code>backward</code>. As we have seen above, the <code>cache</code> variable can be used differently for two activation functions.</p>
# </div>
#
# Use this cell to test your implementation of the `LeakyRelu` class:

# %%
from exercise_code.tests.layer_tests import *
LeakyReluTestWrapper()()
# Out:
# ####### Testing LeakyReluTest Started #######
#
# Test LeakyReluForwardTest: passed!
# Test LeakyReluBackwardTest: passed!
#
# ####### Testing LeakyReluTest Finished #######
# Test LeakyReluTest: passed! -->  Tests passed: 2/2
# Score: 100/100

# %% [markdown]
# And this cell to test your implementation of the `Tanh` class:

# %%
TanhTestWrapper()()
# Out:
# ####### Testing TanhTest Started #######
#
# Test TanhForwardTest: passed!
# Test TanhBackwardTest: passed!
#
# ####### Testing TanhTest Finished #######
# Test TanhTest: passed! -->  Tests passed: 2/2
# Score: 100/100

# %% [markdown]
# Congratulations, you implemented four different activation functions! These activation layers are now ready to be used when you start building your own network.

# %% [markdown]
# ## 1.4 Loss
#
# In order to measure how well a network is performing, we implemented several ```Loss``` classes (```L1```, ```MSE```, ```BCE```, each preferred for a certain type of problems) in ```exercise_code/networks/loss.py```.
#
# Each contains a ```forward()``` method, which outputs a number we can use as a measure for our network's performance.
#
# Since our goal is to change the weights of the network in a way that this loss measure decreases, we are also interested in the gradients of the loss w.r.t the outputs of the network, $ \nabla_{\hat{y}} L({\hat{y}}, {y}) $. This was implemented in ```backward()```.
#
# In previous exercises, we worked on binary classification problems and therefore used binary cross entropy (```BCE```) as a loss function.
#
# $$ BCE(\hat{y}, y) = - \frac{1}{N} \sum_{i=1}^N \Big(y_i \log(\hat{y_i}) + (1-y_i) \log(1 - \hat{y_i}) \Big) $$
#
# where
# - $ N $ was the number of samples we were considering
# - $\hat{y}_i$ was the network's prediction for sample $i$. Note that this was a valid probability $\in [0, 1]$, because we applied a [sigmoid](https://en.wikipedia.org/wiki/Sigmoid_function) activation on the last layer.
# - $ y_i $ was the ground truth label (0 or 1, depending on the class)
#
# Since we have 10 classes in the CIFAR10 dataset, we need a generalization of the binary cross entropy loss to multiple classes. This generalization is called the cross entropy loss and is defined as:
# $$ CE(\hat{y}, y) = - \frac{1}{N} \sum_{i=1}^N \sum_{k=1}^{C} \Big(y_{ik} \log(\hat{y}_{ik}) \Big) $$
#
# where:
# - $ N $ is the number of samples
# - $ C $ is the number of classes
# - $ \hat{y}_{ik} $ is the probability that the model assigns for the $k$ th class when the $i$ th sample is the input. **Because we don't apply any activation function on the last layer of our network, its outputs for each sample will not be a valid probability distribution over the classes. We call these raw outputs of the network '[logits](https://datascience.stackexchange.com/questions/31041/what-does-logits-in-machine-learning-mean/31045)' and we will apply a [softmax](https://en.wikipedia.org/wiki/Softmax_function) activation in order to obtain a valid probability distribution.**
# - $y_{ik} = 1 $ iff the true label of the $i$ th sample is $k$ and 0 otherwise. This is called a [one-hot encoding](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/).
#
# You can check for yourself that if the number of classes $ C $ is 2, the binary cross entropy is actually equivalent to the cross entropy.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the <code>CrossEntropyFromLogits</code> class, which can be found in <code>../exercise_06/exercise_code/networks/loss.py</code>. </p>
# </div>

# %%
loss = CrossEntropyFromLogits

# %% [markdown]
# We can simply get the results of the forward and backward passes as follows:

# %% [markdown]
# ```python
# # y_out is the output of the neural network
# # y_truth is the actual label from the dataset
# loss.forward(y_out, y_truth)
# loss.backward(y_out, y_truth)
# ```

# %% [markdown]
# ## 1.5 Optimizer
#
# Now that we know the gradient of the loss w.r.t the ouputs of the network, as well as the local gradient for each layer of the network, we can use the chain rule to compute all gradients.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>We implemented several optimizer classes <code>SGD</code>, <code>Adam</code>, <code>sgd_momentum</code> that use different first-order parameter update rules. Those can be found in <code>../exercise_06/exercise_code/networks/optimizer.py</code>. </p>
#     <p>The <code>step()</code> method used, iterates through all the parameters of the model and updates them using the gradient information.</p>
# </div>
#
# What the optimizer is doing, in pseudocode, is the following:
#
# ```python
# for param in model:
#     # Use the gradient to update the weights.
#     update(param)
#
#     # Reset the gradient after each update.
#     param.gradient = 0
# ```
#
# ```SGD``` had the simplest update rule:
# ```python
# def update(param):
#     param = param - learning_rate * param.gradient
# ```
#
# For the more complicated update rules, see ```exercise_code/networks/optimizer.py```

# %% [markdown]
# ## 1.6 Solver
#
# The ```Solver``` is where all the above elements come together: Given a train and a validation dataloader, a model, a loss and an optimizer, it uses the training data to optimize a model in order to get better predictions. We simply call ```train()``` and it does its 'magic' for us!
# ```python
# solver = Solver(model,
#                 dataloaders['train'],
#                 dataloaders['val'],
#                 learning_rate=0.001,
#                 loss_func=MSE(),
#                 optimizer=SGD)
#
# solver.train(epochs=epochs)
# ```
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check out the implementation of <code>train()</code> in <code>../exercise_06/exercise_code/solver.py</code>. </p>
# </div>

# %% [markdown]
# ## 1.7 Weight Regularization
#
# Before finishing the recap, we want to take a look at some regularization methods that have been introduced in the lecture. Those can be helpful to improve the robustness of our model. In this chapter, we're talking about weight regularization methods.
#
# Weight regularization (a.k.a "Weight Decay") has been introduced to you as a method preventing the model from overfitting to the training data.
#
# The regularization term over the weights of the network is added to the loss:
#
# $$ L^* = \underbrace{L}_{\text{Overall loss}} + \underbrace{\lambda R(\theta)}_{\text{Regularization loss}} $$
#
# where $\theta$ represents **ALL** the weights of the network, $\theta = \{W_1, \dots, W_n\}$ and $R(\theta) \in \mathbb{R}.$
#
# Therefore, the backward step for each weight matrix $W_k \in  \theta$ is:
#
# $$\frac{\partial L}{\partial W_k}^* = \underbrace{\frac{\partial L}{\partial W_k}}_{\text{Gradient}}  + \underbrace{\lambda \frac{\partial R(\theta)}{\partial W_k}}_{\text{Reg. loss gradient}}$$
#
# The usage of the regularization term encodes some preferences in manipulating the weights. In the lecture, we compared two weight regularization methods and their respective preference for weight vectors. We made the following observations:
#
# 1. L1 regularization: Enforces sparsity
# 2. L2 regularization: Enforces that weights have similar values
#
# The most common weight regularization method is the L2 regularization. The L2 regularization prefers smaller and more diffuse weight vectors. Therefore, the model is encouraged to take all input dimensions into account rather than focusing strongly on a small number of input dimensions.
#
# When using weight regularization, the loss function is a composition of two parts:
#
# The first being the data loss, which is calculated using Cross Entropy loss in our model. The second part is called the regularization loss $R(\theta)$ and is computed in the L2 case as follows:
# $$R(\theta) = \sum_{k} \sum_{i} \sum_{j} w_{k,i,j}^2$$
#
# Where $k$ runs over all weight matrices in the network, and $i, j$ correspond to the spatial height and width of each weight matrix $W_k$.

# %% [markdown]
# # 2. An overview of hyperparameters

# %% [markdown]
# <img src=https://images.deepai.org/glossary-terms/05c646fe1676490aa0b8cab0732a02b2/hyperparams.png alt=hyperparameter width=700>
#
# A **hyperparameter** is a parameter that is set before the learning process begins. Recall that the parameters of the weight matrix and the bias vector are learned during the learning process.
#
# The hyperparameter settings are essential, since they control and affect the whole training and therefore have a great impact on the model's performance.
#
# Some hyperparameters we have covered in lectures are:
# * Network architecture
#     * Choice of activation function
#     * Number of layers
#     * ...
# * Learning rate
# * Number of epochs
# * Batch size
# * Regularization strength
# * Momentum
# * ...

# %% [markdown]
# ## 2.1 Start debugging your own network!

# %% [markdown]
# As already suggested in the lectures, you should always start from small and simple architectures, to make sure you are going the right way.
#
# As a first step you should try to overfit to a single training sample, then to a few batches of training samples and finally go deeper with larger neural networks and the whole training data.
#
# We provide a default neural network (i.e. ClassificationNet) with arbitrary number of layers, which is a generalization from a fixed 2-layer neural network in exercise 5. You are welcome to implement your own network, in that case just implement **MyOwnNetwork** in ```exercise_code/networks/classification_net.py```. You can also copy things from ClassficationNet and make little adjustments to your own network. Either way, just pick one network and comment out the other one, then run the cells below for debugging.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>Please, make sure you don't modify the ClassificationNet itself. In this way you can always have a working network to fall back on.</p>
#     <p>In order to pass this submissions, you can <b>first stick to the default ClassificationNet implementation without changing any code at all</b>. The goal of this submission is to find reasonable hyperparameters and the parameter options of the ClassificationNet are broad enough to pass.</p>
#     <p>Once you have surpassed the submission goal, you can try to implement additional activation functions in the accompanying notebook, try different weight initializations or make other adjustments by writing your own network architecture in the MyOwnNetwork class.</p>
# </div>

# %% [markdown]
# First, let's start with a 2-layer neural network, and overfit to one single training sample.
#
# After training, let's evaluate the training process by plotting the loss curves.

# %%
from exercise_code.solver import Solver
from exercise_code.networks.optimizer import SGD, Adam
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 20
reg = 1e-6
batch_size = 4

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits

# Make a new data loader with a single training image
overfit_dataset = DATASET(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=1
)
dataloaders['train_overfit_single_image'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)


# Decrease validation data for only debugging
debugging_validation_dataset = DATASET(
    mode='val',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=100
)
dataloaders['val_500files'] = DataLoader(
    dataset=debugging_validation_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

solver = Solver(model, dataloaders['train_overfit_single_image'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 20) train loss: 2.299297; val loss: 2.305431
# (Epoch 2 / 20) train loss: 2.183636; val loss: 2.310438
# (Epoch 3 / 20) train loss: 2.038913; val loss: 2.317063
# (Epoch 4 / 20) train loss: 1.872518; val loss: 2.325562
# (Epoch 5 / 20) train loss: 1.698008; val loss: 2.336217
# (Epoch 6 / 20) train loss: 1.526654; val loss: 2.349295
# (Epoch 7 / 20) train loss: 1.364180; val loss: 2.365041
# (Epoch 8 / 20) train loss: 1.212414; val loss: 2.383679
# (Epoch 9 / 20) train loss: 1.071151; val loss: 2.405399
# (Epoch 10 / 20) train loss: 0.940043; val loss: 2.430314
# (Epoch 11 / 20) train loss: 0.821404; val loss: 2.458426
# (Epoch 12 / 20) train loss: 0.715193; val loss: 2.489658
# (Epoch 13 / 20) train loss: 0.620065; val loss: 2.523855
# (Epoch 14 / 20) train loss: 0.535144; val loss: 2.560768
# (Epoch 15 / 20) train loss: 0.459948; val loss: 2.600043
# (Epoch 16 / 20) train loss: 0.394755; val loss: 2.641220
# (Epoch 17 / 20) train loss: 0.339162; val loss: 2.683805
# (Epoch 18 / 20) train loss: 0.291858; val loss: 2.727318
# (Epoch 19 / 20) train loss: 0.251695; val loss: 2.771300
# (Epoch 20 / 20) train loss: 0.217704; val loss: 2.815328

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_single_image'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 0.07000

# %% [markdown]
# This time we want to overfit to a small set of training batch samples. Please observe the difference from above.

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 100
reg = 0.1
num_samples = 10

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits

# Make a new data loader with a our num_samples training image
overfit_dataset = DATASET(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_overfit_10samples'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

solver = Solver(model, dataloaders['train_overfit_10samples'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 100) train loss: 2.285654; val loss: 2.339864
# (Epoch 2 / 100) train loss: 2.184179; val loss: 2.404058
# (Epoch 3 / 100) train loss: 2.073793; val loss: 2.462862
# (Epoch 4 / 100) train loss: 1.897433; val loss: 2.519303
# (Epoch 5 / 100) train loss: 1.947012; val loss: 2.604608
# (Epoch 6 / 100) train loss: 1.825010; val loss: 2.652202
# (Epoch 7 / 100) train loss: 1.797096; val loss: 2.726142
# (Epoch 8 / 100) train loss: 1.650958; val loss: 2.821884
# (Epoch 9 / 100) train loss: 1.715406; val loss: 2.899799
# (Epoch 10 / 100) train loss: 1.778572; val loss: 2.929512
# (Epoch 11 / 100) train loss: 1.680088; val loss: 2.936305
# (Epoch 12 / 100) train loss: 1.626903; val loss: 3.065746
# (Epoch 13 / 100) train loss: 1.608086; val loss: 3.175972
# (Epoch 14 / 100) train loss: 1.668271; val loss: 3.193894
# (Epoch 15 / 100) train loss: 1.583900; val loss: 3.144835
# (Epoch 16 / 100) train loss: 1.663721; val loss: 3.157860
# (Epoch 17 / 100) train loss: 1.707083; val loss: 3.212566
# (Epoch 18 / 100) train loss: 1.645879; val loss: 3.292113
# (Epoch 19 / 100) train loss: 1.727949; val loss: 3.282400
# (Epoch 20 / 100) train loss: 1.546355; val loss: 3.294221
# (Epoch 21 / 100) train loss: 1.526541; val loss: 3.351726
# (Epoch 22 / 100) train loss: 1.633128; val loss: 3.333373
# (Epoch 23 / 100) train loss: 1.557307; val loss: 3.321494
# (Epoch 24 / 100) train loss: 1.412432; val loss: 3.384119
# (Epoch 25 / 100) train loss: 1.544772; val loss: 3.439287
# (Epoch 26 / 100) train loss: 1.629777; val loss: 3.409613
# (Epoch 27 / 100) train loss: 1.451470; val loss: 3.390785
# (Epoch 28 / 100) train loss: 1.478424; val loss: 3.368684
# (Epoch 29 / 100) train loss: 1.580490; val loss: 3.395362
# (Epoch 30 / 100) train loss: 1.468258; val loss: 3.415669
# (Epoch 31 / 100) train loss: 1.495814; val loss: 3.395274
# (Epoch 32 / 100) train loss: 1.442939; val loss: 3.400465
# (Epoch 33 / 100) train loss: 1.410726; val loss: 3.425180
# (Epoch 34 / 100) train loss: 1.393133; val loss: 3.431054
# (Epoch 35 / 100) train loss: 1.341627; val loss: 3.431287
# (Epoch 36 / 100) train loss: 1.320291; val loss: 3.432498
# (Epoch 37 / 100) train loss: 1.278979; val loss: 3.449951
# (Epoch 38 / 100) train loss: 1.331402; val loss: 3.460398
# (Epoch 39 / 100) train loss: 1.252910; val loss: 3.493269
# (Epoch 40 / 100) train loss: 1.359044; val loss: 3.467955
# (Epoch 41 / 100) train loss: 1.396846; val loss: 3.424090
# (Epoch 42 / 100) train loss: 1.294898; val loss: 3.481334
# (Epoch 43 / 100) train loss: 1.267907; val loss: 3.530805
# (Epoch 44 / 100) train loss: 1.342296; val loss: 3.501542
# (Epoch 45 / 100) train loss: 1.275055; val loss: 3.496119
# (Epoch 46 / 100) train loss: 1.303685; val loss: 3.506314
# (Epoch 47 / 100) train loss: 1.174924; val loss: 3.510949
# (Epoch 48 / 100) train loss: 1.184015; val loss: 3.480063
# (Epoch 49 / 100) train loss: 1.171678; val loss: 3.464200
# (Epoch 50 / 100) train loss: 1.123684; val loss: 3.463859
# (Epoch 51 / 100) train loss: 1.256967; val loss: 3.494803
# (Epoch 52 / 100) train loss: 1.190691; val loss: 3.581557
# (Epoch 53 / 100) train loss: 1.270966; val loss: 3.630106
# (Epoch 54 / 100) train loss: 1.276279; val loss: 3.608391
# (Epoch 55 / 100) train loss: 1.158384; val loss: 3.558018
# (Epoch 56 / 100) train loss: 1.167835; val loss: 3.527753
# (Epoch 57 / 100) train loss: 1.105719; val loss: 3.534693
# (Epoch 58 / 100) train loss: 1.118713; val loss: 3.554104
# (Epoch 59 / 100) train loss: 1.146755; val loss: 3.561773
# (Epoch 60 / 100) train loss: 1.032525; val loss: 3.559286
# (Epoch 61 / 100) train loss: 1.032632; val loss: 3.533494
# (Epoch 62 / 100) train loss: 1.081893; val loss: 3.520433
# (Epoch 63 / 100) train loss: 1.002093; val loss: 3.539199
# (Epoch 64 / 100) train loss: 1.009278; val loss: 3.555585
# (Epoch 65 / 100) train loss: 1.005067; val loss: 3.551066
# (Epoch 66 / 100) train loss: 1.025556; val loss: 3.563292
# (Epoch 67 / 100) train loss: 1.018766; val loss: 3.608181
# (Epoch 68 / 100) train loss: 1.029249; val loss: 3.640321
# (Epoch 69 / 100) train loss: 1.012257; val loss: 3.621215
# (Epoch 70 / 100) train loss: 1.063621; val loss: 3.578943
# (Epoch 71 / 100) train loss: 1.074002; val loss: 3.575941
# (Epoch 72 / 100) train loss: 1.015561; val loss: 3.608953
# (Epoch 73 / 100) train loss: 0.989825; val loss: 3.623651
# (Epoch 74 / 100) train loss: 0.955146; val loss: 3.594755
# (Epoch 75 / 100) train loss: 0.955101; val loss: 3.537475
# (Epoch 76 / 100) train loss: 0.929371; val loss: 3.523151
# (Epoch 77 / 100) train loss: 0.902755; val loss: 3.543167
# (Epoch 78 / 100) train loss: 0.922729; val loss: 3.564267
# (Epoch 79 / 100) train loss: 0.901654; val loss: 3.585462
# (Epoch 80 / 100) train loss: 0.899365; val loss: 3.554451
# (Epoch 81 / 100) train loss: 0.916332; val loss: 3.569907
# (Epoch 82 / 100) train loss: 0.914208; val loss: 3.578835
# (Epoch 83 / 100) train loss: 0.970760; val loss: 3.567008
# (Epoch 84 / 100) train loss: 0.876876; val loss: 3.564520
# (Epoch 85 / 100) train loss: 0.941295; val loss: 3.571987
# (Epoch 86 / 100) train loss: 0.852770; val loss: 3.578122
# (Epoch 87 / 100) train loss: 0.911657; val loss: 3.561768
# (Epoch 88 / 100) train loss: 0.887248; val loss: 3.528751
# (Epoch 89 / 100) train loss: 0.883506; val loss: 3.549366
# (Epoch 90 / 100) train loss: 0.854375; val loss: 3.580397
# (Epoch 91 / 100) train loss: 0.864722; val loss: 3.578156
# (Epoch 92 / 100) train loss: 0.910486; val loss: 3.574541
# (Epoch 93 / 100) train loss: 0.915645; val loss: 3.629390
# (Epoch 94 / 100) train loss: 1.004421; val loss: 3.603267
# (Epoch 95 / 100) train loss: 0.891343; val loss: 3.615974
# (Epoch 96 / 100) train loss: 0.919546; val loss: 3.627531
# (Epoch 97 / 100) train loss: 0.964854; val loss: 3.612748
# (Epoch 98 / 100) train loss: 0.886305; val loss: 3.613592
# (Epoch 99 / 100) train loss: 0.834075; val loss: 3.562202
# (Epoch 100 / 100) train loss: 0.898983; val loss: 3.540259

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_10samples'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 0.07000

# %% [markdown]
# If you're overfitting to the training data, that means the network's implementation is correct. However, as you have more samples to overfit, your accuracy will be way lower. You can increase the number of epochs above to achieve better results.
#
# Now let's try to feed all the training and validation data into the network, but this time let's set compare a 2-layer and a 5-layer network, using the same hyperparameters.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>This may take about 1 min per epoch as the training set is quite large. For convenience, we are now only using 1000 images for training but use the full validation set.</p>
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 5
reg = 1e-4

# Make a new data loader with 1000 training samples
num_samples = 500
overfit_dataset = DATASET(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_small'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)




# Change here if you want to use the full training set
use_full_training_set = False
if use_full_training_set:
    train_loader =  dataloaders['train']
else:
    train_loader = dataloaders['train_small']
    

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

loss = CrossEntropyFromLogits

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.258033; val loss: 2.152057
# (Epoch 2 / 5) train loss: 2.086578; val loss: 2.084361
# (Epoch 3 / 5) train loss: 1.977454; val loss: 2.048182
# (Epoch 4 / 5) train loss: 1.891146; val loss: 2.026482
# (Epoch 5 / 5) train loss: 1.795712; val loss: 2.028021

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.46600
# Validation accuray: 0.27815

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 5
epochs = 5
reg = 1e-4

model = ClassificationNet(num_layer=num_layer, reg=reg)
# model = MyOwnNetwork()

# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']

loss = CrossEntropyFromLogits

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.315489; val loss: 2.305227
# (Epoch 2 / 5) train loss: 2.302554; val loss: 2.307221
# (Epoch 3 / 5) train loss: 2.302796; val loss: 2.305772
# (Epoch 4 / 5) train loss: 2.301402; val loss: 2.307386
# (Epoch 5 / 5) train loss: 2.301414; val loss: 2.306428

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.11600
# Validation accuray: 0.09806

# %% [markdown]
# As you can see from above, the same hyperparameter set can decrease the loss for a 2-layer network, but for 5-layer network, it hardly works.
#
# The steps above are already mentioned in the lectures as debugging steps before training a neural network.
#
# If you implement your own network, make sure you do the steps above before tuning the hyperparameters as below.

# %% [markdown]
# ## 2.2 Difficulty in tuning hyperparameters
# Small decisions on hyperparameters count. Usually, but not always, hyperparameters cannot be learned using well known gradient based methods (such as gradient descent), which are commonly employed to learn parameters.
#
# As mentioned before, hyperparameters need to be set before training. Tuning hyperparameters is hard, because you always have to try different combinations of the hyperparameters, train the network, do the validation and pick the best one. Besides, it is not guaranteed that you'll find the best combination.
#
# Let's do some hands on learning using the hyperparameter tuning methods covered in the lectures.

# %% [markdown]
# # 3. Hyperparameter Tuning
#
# One of the main challenges in deep learning is finding the set of hyperparameters that performs best.
#
# So far, we have followed a manual approach by guessing hyperparameters, running the model, observing the result and maybe tweaking the hyperparameters based on this result. As you have probably noticed, this manual hyperparameter tuning is unstructured, inefficient and can become very tedious.
#
#
# A more systematic (and actually very simple) approach for hyperparameter tuning that you've already learned in the lecture  is implementing a **Grid Search**.
#
#
#
# ## 3.1 Grid Search
# Grid search is a simple and naive, yet effective method to automate the hyperparameter tuning:
#
# * First, you define the set of parameters you want to tune, e.g. $\{learning\_rate, regularization\_strength\}$.
#
# * For each hyperparameter, you then define a set of possible values, e.g. $learning\_rate = \{0.0001, 0.001, 0.01, 0.1\}$.
#
# * Then, you train a model for every possible combination of these hyperparameter values and afterwards select the combination that works best (e.g. in terms of accuracy on your validation set).
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Check out our <code>grid_search</code> implementation in <code>../exercise_6/exercise_code/hyperparameter_tuning.py</code>. We show a simple for loop implementation and a more sophisticated one for multiple inputs. </p>
# </div>
#
#  <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>To keep things simple in the beginning, it'll be enough to just focus on the hyperparameters <code>learning_rate</code> and <code>regularization_strength</code> here, as in the example above.</p>
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

from exercise_code import hyperparameter_tuning
best_model, best_config, results  = hyperparameter_tuning.grid_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    grid_search_spaces = {
        "learning_rate": [1e-2, 1e-3, 1e-4], 
        "reg": [1e-4]
    },
    model_class=model_class,
    epochs=10, patience=5)
# Out:
# Evaluating Config #1 [of 3]:
#  {'learning_rate': 0.01, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.530499; val loss: 2.354641
# (Epoch 2 / 10) train loss: 2.509591; val loss: 2.593119
# (Epoch 3 / 10) train loss: 2.650252; val loss: 2.714910
# (Epoch 4 / 10) train loss: 2.719391; val loss: 2.649550
# (Epoch 5 / 10) train loss: 2.801244; val loss: 3.037952
# /Users/darynasemenets/Documents/python/i2dl/exercise_06/exercise_code/networks/layer.py:66: RuntimeWarning: overflow encountered in exp
#   outputs = 1 / (1 + np.exp(-x))
# (Epoch 6 / 10) train loss: 2.945288; val loss: 3.203802
# Stopping early at epoch 5!
#
# Evaluating Config #2 [of 3]:
#  {'learning_rate': 0.001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.271425; val loss: 2.166569
# (Epoch 2 / 10) train loss: 2.098826; val loss: 2.030061
# (Epoch 3 / 10) train loss: 1.974465; val loss: 1.983778
# (Epoch 4 / 10) train loss: 1.871272; val loss: 1.935068
# (Epoch 5 / 10) train loss: 1.766893; val loss: 1.933275
# (Epoch 6 / 10) train loss: 1.693567; val loss: 1.946089
# (Epoch 7 / 10) train loss: 1.597877; val loss: 1.904276
# (Epoch 8 / 10) train loss: 1.511379; val loss: 1.879942
# (Epoch 9 / 10) train loss: 1.418325; val loss: 1.974331
# (Epoch 10 / 10) train loss: 1.337345; val loss: 1.988660
#
# Evaluating Config #3 [of 3]:
#  {'learning_rate': 0.0001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.298609; val loss: 2.286474
# (Epoch 2 / 10) train loss: 2.271493; val loss: 2.249799
# (Epoch 3 / 10) train loss: 2.231502; val loss: 2.208557
# (Epoch 4 / 10) train loss: 2.186343; val loss: 2.166668
# (Epoch 5 / 10) train loss: 2.141681; val loss: 2.140537
# (Epoch 6 / 10) train loss: 2.101638; val loss: 2.108549
# (Epoch 7 / 10) train loss: 2.066011; val loss: 2.085156
# (Epoch 8 / 10) train loss: 2.034256; val loss: 2.066654
# (Epoch 9 / 10) train loss: 2.002687; val loss: 2.058920
# (Epoch 10 / 10) train loss: 1.972769; val loss: 2.049604
#
# Search done. Best Val Loss = 1.8799419174540781
# Best Config: {'learning_rate': 0.001, 'reg': 0.0001}

# %% [markdown]
# From the results of your grid search, you might already have found some hyperparameter combinations that work better than others. A common practice is to now repeat the grid search on a more narrow domain centered around the parameters that worked best.
#
# **Conclusion Grid Search**
#
# With grid search we have automated the hyperparameter tuning to a certain degree. Another advantage is, that since the trainings of the models are independent of each other, you can parallelize the grid search, by e.g. trying out different hyperparameter configurations in parallel on different machines.
#
# However, as you have probably noticed, there is one big problem with this approach: the number of possible combinations grows exponentially with the number of hyperparameters ("curse of dimensionality"). As we add more hyperparameters to the grid search, the search space will explode in time complexity, making this strategy unfeasible.

# %% [markdown]
# Especially when your search space contains more than 3 or 4 dimensions, it is often better to use another, similar hyperparameter tuning method that you've already learned about: random search.

# %% [markdown]
# ## 3.2 Random Search
# Random search is very similar to grid search, with the only difference, that instead of providing specific values for every hyperparameter, you only define a range for each hyperparameter - then, the values are sampled randomly from the provided ranges.
#
# ![alt text](https://i.stack.imgur.com/cIDuR.png "")
#
# The figure above illustrates the difference in the hyperparameter space exploration between grid search and random search: assume you have 2 hyperparameters with each 3 values. Running a grid search results in training $3^2=9$ different models - but in the end, you've just tired out 3 values for each parameter. For random search on the other hand, after training 9 models you'll have tried out 9 different values for each hyperparameter, which often leads much faster to good results.
#
# To get a deeper understanding of random search and why it is more efficient than grid search, you should definitely check out this paper: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Check out our <code>random_search</code> implementation in <code>../exercise_6/exercise_code/hyperparameter_tuning.py</code></p>
# </div>
#
#
# *Hint: regarding the sample space of each parameter, think about the scale for which it makes most sense to sample in. For example the learning rate is usually sampled on a logarithmic scale!*
#
# *For simplicity and speed, just use the `train_small`-dataloader!*

# %%
from exercise_code.hyperparameter_tuning import random_search
from exercise_code.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

best_model, best_config, results  = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-2, 1e-6], 'log'),
        "reg": ([1e-3, 1e-7], "log"),
        "loss_func": ([CrossEntropyFromLogits], "item"),
        "num_layer": ([3], "int"),
    },
    model_class=model_class,
    num_search = 5, epochs=20, patience=5)
# Out:
# Evaluating Config #1 [of 5]:
#  {'learning_rate': 5.2766850166680066e-05, 'reg': 0.00013249062612703634, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 3}
# (Epoch 1 / 20) train loss: 2.302818; val loss: 2.303239
# (Epoch 2 / 20) train loss: 2.300902; val loss: 2.304138
# (Epoch 3 / 20) train loss: 2.299080; val loss: 2.304531
# (Epoch 4 / 20) train loss: 2.298483; val loss: 2.304889
# (Epoch 5 / 20) train loss: 2.298357; val loss: 2.306143
# (Epoch 6 / 20) train loss: 2.297527; val loss: 2.306143
# Stopping early at epoch 5!
#
# Evaluating Config #2 [of 5]:
#  {'learning_rate': 1.5098785267684448e-06, 'reg': 0.00028130198107451543, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 3}
# (Epoch 1 / 20) train loss: 2.302450; val loss: 2.302968
# (Epoch 2 / 20) train loss: 2.302360; val loss: 2.302951
# (Epoch 3 / 20) train loss: 2.302264; val loss: 2.302936
# (Epoch 4 / 20) train loss: 2.302181; val loss: 2.302952
# (Epoch 5 / 20) train loss: 2.302103; val loss: 2.302948
# (Epoch 6 / 20) train loss: 2.302008; val loss: 2.302911
# (Epoch 7 / 20) train loss: 2.301925; val loss: 2.302932
# (Epoch 8 / 20) train loss: 2.301842; val loss: 2.302929
# (Epoch 9 / 20) train loss: 2.301770; val loss: 2.302924
# (Epoch 10 / 20) train loss: 2.301689; val loss: 2.302922
# (Epoch 11 / 20) train loss: 2.301610; val loss: 2.302932
# Stopping early at epoch 10!
#
# Evaluating Config #3 [of 5]:
#  {'learning_rate': 4.484620400595423e-06, 'reg': 1.409348339384797e-07, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 3}
# (Epoch 1 / 20) train loss: 2.302916; val loss: 2.303131
# (Epoch 2 / 20) train loss: 2.302605; val loss: 2.303064
# (Epoch 3 / 20) train loss: 2.302323; val loss: 2.303024
# (Epoch 4 / 20) train loss: 2.302101; val loss: 2.303079
# (Epoch 5 / 20) train loss: 2.301849; val loss: 2.303000
# (Epoch 6 / 20) train loss: 2.301612; val loss: 2.302964
# (Epoch 7 / 20) train loss: 2.301392; val loss: 2.303037
# (Epoch 8 / 20) train loss: 2.301155; val loss: 2.303034
# (Epoch 9 / 20) train loss: 2.300945; val loss: 2.302960
# (Epoch 10 / 20) train loss: 2.300743; val loss: 2.303057
# (Epoch 11 / 20) train loss: 2.300526; val loss: 2.303053
# (Epoch 12 / 20) train loss: 2.300395; val loss: 2.303021
# (Epoch 13 / 20) train loss: 2.300175; val loss: 2.303039
# (Epoch 14 / 20) train loss: 2.300018; val loss: 2.303114
# Stopping early at epoch 13!
#
# Evaluating Config #4 [of 5]:
#  {'learning_rate': 0.00010910044956120498, 'reg': 4.1688878048797764e-05, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 3}
# (Epoch 1 / 20) train loss: 2.303885; val loss: 2.302451
# (Epoch 2 / 20) train loss: 2.300370; val loss: 2.305946
# (Epoch 3 / 20) train loss: 2.299617; val loss: 2.306300
# (Epoch 4 / 20) train loss: 2.299092; val loss: 2.306603
# (Epoch 5 / 20) train loss: 2.299202; val loss: 2.309329
# (Epoch 6 / 20) train loss: 2.298576; val loss: 2.307671
# Stopping early at epoch 5!
#
# Evaluating Config #5 [of 5]:
#  {'learning_rate': 0.000154129116835482, 'reg': 1.0751916365760084e-05, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 3}
# (Epoch 1 / 20) train loss: 2.304705; val loss: 2.304289
# (Epoch 2 / 20) train loss: 2.301306; val loss: 2.305281
# (Epoch 3 / 20) train loss: 2.300107; val loss: 2.309196
# (Epoch 4 / 20) train loss: 2.300372; val loss: 2.303473
# (Epoch 5 / 20) train loss: 2.299152; val loss: 2.308556
# (Epoch 6 / 20) train loss: 2.299062; val loss: 2.307913
# (Epoch 7 / 20) train loss: 2.296178; val loss: 2.306047
# (Epoch 8 / 20) train loss: 2.291856; val loss: 2.308720
# (Epoch 9 / 20) train loss: 2.285018; val loss: 2.304257
# Stopping early at epoch 8!
#
# Search done. Best Val Loss = 2.3024507434423223
# Best Config: {'learning_rate': 0.00010910044956120498, 'reg': 4.1688878048797764e-05, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 3}

# %% [markdown]
# It's time to run it with the whole dataset, and let it search for a few hours for a nice configuration.
#
# However, to save some time, let's first implement an **early-stopping** mechanism, that you also already know from the lecture.

# %% [markdown]
# ## 3.3 Early Stopping

# %% [markdown]
# By now you've already seen a lot of training curves:
#
# <img src=http://fouryears.eu/wp-content/uploads/2017/12/early_stopping.png></img>
#
# Usually, at some point the validation loss goes up again, which is a sign that we're overfitting to our training data. Since it actually doesn't make sense to train further at this point, it's common practice to apply "early stopping", i.e., cancel the training process when the validation loss doesn't improve anymore. The nice thing about this concept is, that not only it improves generalization through the prevention of overfitting, but also it saves us a lot of time - one of our most valuable resources in deep learning.
#
# Since there are natural fluctuations in the validation loss, you usually don't cancel the training process right at the first epoch when the validation-loss increases, but instead, you wait for some epochs (specified by the `patience`-parameter) and if the loss still doesn't improve, we stop.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the early stopping mechanism in <code>../exercise_6/exercise_code/solver.py</code>.
#  </p>
# </div>

# %% [markdown]
# ## 3.4 Let's find the perfect model!

# %% [markdown]
# Now you've set everything up and you are ready to train your model. You can use a combination of grid and random search to find proper hyperparameters.
#
# Be aware that this process will take some time, since we'll be using a much larger dataset.
#
# At the beginning, it is a good approach to do a coarse random search across a wide range of values to find promising sub-ranges of your parameter space. Afterwards, you can zoom into these ranges and perform another random search (or grid search) to finetune the configurations.
#
# To save time and resources, don't use the whole dataset at the beginning, but instead a medium large subset of the samples. Also, you don't have to train for a large number of epochs - as mentioned above: we first want to get an overview about our hyper parameters.
#
# <div class="alert alert-info">
#     <h3>Task: Hyperparameters Tunning & Model Training </h3>
#         <p> Now, it is your turn to do the hyperparamater tuning. In the cell below, you can use the <code>random_search</code> function to find a good choice of parameters. Put in some reasonable ranges for the hyperparameters and evaluate them.
#     <p> <b>Note:</b> At the beginning, it's a good approach to first do a coarse random search across a <b> wide range of values</b> to find promising sub-ranges of your parameter space and use <b> a medium large subset of the dataset </b>. Afterwards, you can zoom into these ranges and do another random search (or grid search) to finetune the configurations. Use the cell below to play around and find good hyperparameters for your model!</p>
#         <p> Finally, once you've found some promising hyperparameters (or narrowed them down to promising subranges), it's time to utilize these hyperparameters to train your network on the whole dataset for a large number of epochs so that your own model can reach an acceptable performance.
#         <p> <b>Hint 1:</b> You may use a <code>Solver</code> class we provided before or directly use the <code>random_search</code> function (as you can also monitor the loss here) for model training.
#         <p> <b>Hint 2:</b> Be patience, this will take time.
#         <p> <b>Hint 3:</b> It is a better practice to a find good set of hyperparameters on the small datasets, and only then run a full training session on the full dataset, either with specific hyperparameters that you've found in the <code>random search</code>, or better ranges.
# </div>

# %%
from exercise_code.networks import MyOwnNetwork, ClassificationNet
from exercise_code.networks import optimizer

model_type = ClassificationNet

best_model, best_config, results  = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-3, 1e-7], 'log'),
        "reg": ([1e-3, 1e-7], "log"),
        "loss_func": ([CrossEntropyFromLogits], "item"),
        "num_layer": ([2], "int"),
        "activation": ([Relu, LeakyRelu], "item"),
        "optimizer": ([optimizer.Adam, optimizer.sgd_momentum, optimizer.SGD], "item"),
        "dropout": ([0.0, 0.1, 0.4], "item"),
        "hidden_size": ([64, 128, 256, 512], "item")
    },
    model_class=model_type,
    num_search = 20, patience=10, epochs= 100)

#model.save_model('./models/best_model')

########################################################################
# TODO:                                                                #
# Implement your own neural network and find suitable hyperparameters  #
# Be sure to edit the MyOwnNetwork class in the following code snippet #
# to upload the correct model! Or just use the given                   #
# "ClassificationNet".                                                 #
#                                                                      #
# Note: the pickling cell expects your model to be named "best_model". #
# Unless you change it there, naming the best model in any other way   #
# will result in an unknown behavior.                                  #
########################################################################
# Out:
# Evaluating Config #1 [of 20]:
#  {'learning_rate': 4.6734599177159585e-07, 'reg': 2.5027553825540124e-07, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.Relu'>, 'optimizer': <class 'exercise_code.networks.optimizer.Adam'>, 'dropout': 0.1, 'hidden_size': 512}
# (Epoch 1 / 100) train loss: 2.302403; val loss: 2.302197
# (Epoch 2 / 100) train loss: 2.301812; val loss: 2.301728
# (Epoch 3 / 100) train loss: 2.301242; val loss: 2.301250
# (Epoch 4 / 100) train loss: 2.300664; val loss: 2.300763
# (Epoch 5 / 100) train loss: 2.300069; val loss: 2.300225
# (Epoch 6 / 100) train loss: 2.299457; val loss: 2.299662
# (Epoch 7 / 100) train loss: 2.298813; val loss: 2.299067
# (Epoch 8 / 100) train loss: 2.298144; val loss: 2.298489
# (Epoch 9 / 100) train loss: 2.297443; val loss: 2.297817
# (Epoch 10 / 100) train loss: 2.296687; val loss: 2.297115
# (Epoch 11 / 100) train loss: 2.295894; val loss: 2.296337
# (Epoch 12 / 100) train loss: 2.295052; val loss: 2.295596
# (Epoch 13 / 100) train loss: 2.294161; val loss: 2.294745
# (Epoch 14 / 100) train loss: 2.293232; val loss: 2.293854
# (Epoch 15 / 100) train loss: 2.292254; val loss: 2.292940
# (Epoch 16 / 100) train loss: 2.291220; val loss: 2.291924
# (Epoch 17 / 100) train loss: 2.290134; val loss: 2.290919
# (Epoch 18 / 100) train loss: 2.289009; val loss: 2.289810
# (Epoch 19 / 100) train loss: 2.287824; val loss: 2.288691
# (Epoch 20 / 100) train loss: 2.286598; val loss: 2.287471
# (Epoch 21 / 100) train loss: 2.285320; val loss: 2.286247
# (Epoch 22 / 100) train loss: 2.283989; val loss: 2.285008
# (Epoch 23 / 100) train loss: 2.282638; val loss: 2.283646
# (Epoch 24 / 100) train loss: 2.281202; val loss: 2.282304
# (Epoch 25 / 100) train loss: 2.279748; val loss: 2.280832
# (Epoch 26 / 100) train loss: 2.278242; val loss: 2.279413
# (Epoch 27 / 100) train loss: 2.276709; val loss: 2.277848
# (Epoch 28 / 100) train loss: 2.275122; val loss: 2.276360
# (Epoch 29 / 100) train loss: 2.273519; val loss: 2.274752
# (Epoch 30 / 100) train loss: 2.271853; val loss: 2.273112
# (Epoch 31 / 100) train loss: 2.270149; val loss: 2.271455
# (Epoch 32 / 100) train loss: 2.268426; val loss: 2.269765
# (Epoch 33 / 100) train loss: 2.266658; val loss: 2.268023
# (Epoch 34 / 100) train loss: 2.264874; val loss: 2.266294
# (Epoch 35 / 100) train loss: 2.263038; val loss: 2.264523
# (Epoch 36 / 100) train loss: 2.261199; val loss: 2.262651
# (Epoch 37 / 100) train loss: 2.259293; val loss: 2.260823
# (Epoch 38 / 100) train loss: 2.257385; val loss: 2.258882
# (Epoch 39 / 100) train loss: 2.255439; val loss: 2.256996
# (Epoch 40 / 100) train loss: 2.253483; val loss: 2.255080
# (Epoch 41 / 100) train loss: 2.251483; val loss: 2.253197
# (Epoch 42 / 100) train loss: 2.249488; val loss: 2.251193
# (Epoch 43 / 100) train loss: 2.247486; val loss: 2.249122
# (Epoch 44 / 100) train loss: 2.245417; val loss: 2.247140
# (Epoch 45 / 100) train loss: 2.243350; val loss: 2.245201
# (Epoch 46 / 100) train loss: 2.241291; val loss: 2.243118
# (Epoch 47 / 100) train loss: 2.239178; val loss: 2.241027
# (Epoch 48 / 100) train loss: 2.237089; val loss: 2.238933
# (Epoch 49 / 100) train loss: 2.234959; val loss: 2.236879
# (Epoch 50 / 100) train loss: 2.232834; val loss: 2.234742
# (Epoch 51 / 100) train loss: 2.230699; val loss: 2.232699
# (Epoch 52 / 100) train loss: 2.228547; val loss: 2.230571
# (Epoch 53 / 100) train loss: 2.226384; val loss: 2.228453
# (Epoch 54 / 100) train loss: 2.224218; val loss: 2.226272
# (Epoch 55 / 100) train loss: 2.222052; val loss: 2.224155
# (Epoch 56 / 100) train loss: 2.219884; val loss: 2.222048
# (Epoch 57 / 100) train loss: 2.217701; val loss: 2.219943
# (Epoch 58 / 100) train loss: 2.215530; val loss: 2.217745
# (Epoch 59 / 100) train loss: 2.213341; val loss: 2.215539
# (Epoch 60 / 100) train loss: 2.211155; val loss: 2.213545
# (Epoch 61 / 100) train loss: 2.208997; val loss: 2.211306
# (Epoch 62 / 100) train loss: 2.206810; val loss: 2.209195
# (Epoch 63 / 100) train loss: 2.204652; val loss: 2.207160
# (Epoch 64 / 100) train loss: 2.202499; val loss: 2.204984
# (Epoch 65 / 100) train loss: 2.200332; val loss: 2.202792
# (Epoch 66 / 100) train loss: 2.198145; val loss: 2.200850
# (Epoch 67 / 100) train loss: 2.195994; val loss: 2.198640
# (Epoch 68 / 100) train loss: 2.193847; val loss: 2.196577
# (Epoch 69 / 100) train loss: 2.191726; val loss: 2.194409
# (Epoch 70 / 100) train loss: 2.189553; val loss: 2.192328
# (Epoch 71 / 100) train loss: 2.187396; val loss: 2.190270
# (Epoch 72 / 100) train loss: 2.185276; val loss: 2.188190
# (Epoch 73 / 100) train loss: 2.183152; val loss: 2.186147
# (Epoch 74 / 100) train loss: 2.181024; val loss: 2.184085
# (Epoch 75 / 100) train loss: 2.178885; val loss: 2.182041
# (Epoch 76 / 100) train loss: 2.176774; val loss: 2.180000
# (Epoch 77 / 100) train loss: 2.174680; val loss: 2.177964
# (Epoch 78 / 100) train loss: 2.172588; val loss: 2.175825
# (Epoch 79 / 100) train loss: 2.170486; val loss: 2.173914
# (Epoch 80 / 100) train loss: 2.168428; val loss: 2.171915
# (Epoch 81 / 100) train loss: 2.166365; val loss: 2.169972
# (Epoch 82 / 100) train loss: 2.164299; val loss: 2.167929
# (Epoch 83 / 100) train loss: 2.162234; val loss: 2.165991
# (Epoch 84 / 100) train loss: 2.160198; val loss: 2.163952
# (Epoch 85 / 100) train loss: 2.158150; val loss: 2.162048
# (Epoch 86 / 100) train loss: 2.156110; val loss: 2.160118
# (Epoch 87 / 100) train loss: 2.154067; val loss: 2.158155
# (Epoch 88 / 100) train loss: 2.152056; val loss: 2.156295
# (Epoch 89 / 100) train loss: 2.150044; val loss: 2.154274
# (Epoch 90 / 100) train loss: 2.148063; val loss: 2.152451
# (Epoch 91 / 100) train loss: 2.146047; val loss: 2.150595
# (Epoch 92 / 100) train loss: 2.144090; val loss: 2.148666
# (Epoch 93 / 100) train loss: 2.142079; val loss: 2.146923
# (Epoch 94 / 100) train loss: 2.140109; val loss: 2.145022
# (Epoch 95 / 100) train loss: 2.138149; val loss: 2.143212
# (Epoch 96 / 100) train loss: 2.136208; val loss: 2.141406
# (Epoch 97 / 100) train loss: 2.134276; val loss: 2.139609
# (Epoch 98 / 100) train loss: 2.132350; val loss: 2.137686
# (Epoch 99 / 100) train loss: 2.130402; val loss: 2.136086
# (Epoch 100 / 100) train loss: 2.128532; val loss: 2.134280
#
# Evaluating Config #2 [of 20]:
#  {'learning_rate': 4.2214273407684623e-07, 'reg': 0.00013333392520416804, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.Relu'>, 'optimizer': <class 'exercise_code.networks.optimizer.Adam'>, 'dropout': 0.0, 'hidden_size': 64}
# (Epoch 1 / 100) train loss: 2.302596; val loss: 2.302547
# (Epoch 2 / 100) train loss: 2.302523; val loss: 2.302480
# (Epoch 3 / 100) train loss: 2.302452; val loss: 2.302418
# (Epoch 4 / 100) train loss: 2.302384; val loss: 2.302357
# (Epoch 5 / 100) train loss: 2.302316; val loss: 2.302289
# (Epoch 6 / 100) train loss: 2.302246; val loss: 2.302227
# (Epoch 7 / 100) train loss: 2.302173; val loss: 2.302158
# (Epoch 8 / 100) train loss: 2.302097; val loss: 2.302083
# (Epoch 9 / 100) train loss: 2.302018; val loss: 2.302005
# (Epoch 10 / 100) train loss: 2.301933; val loss: 2.301924
# (Epoch 11 / 100) train loss: 2.301845; val loss: 2.301838
# (Epoch 12 / 100) train loss: 2.301751; val loss: 2.301745
# (Epoch 13 / 100) train loss: 2.301654; val loss: 2.301645
# (Epoch 14 / 100) train loss: 2.301550; val loss: 2.301542
# (Epoch 15 / 100) train loss: 2.301440; val loss: 2.301436
# (Epoch 16 / 100) train loss: 2.301326; val loss: 2.301320
# (Epoch 17 / 100) train loss: 2.301204; val loss: 2.301196
# (Epoch 18 / 100) train loss: 2.301076; val loss: 2.301075
# (Epoch 19 / 100) train loss: 2.300944; val loss: 2.300944
# (Epoch 20 / 100) train loss: 2.300806; val loss: 2.300799
# (Epoch 21 / 100) train loss: 2.300660; val loss: 2.300655
# (Epoch 22 / 100) train loss: 2.300509; val loss: 2.300502
# (Epoch 23 / 100) train loss: 2.300352; val loss: 2.300342
# (Epoch 24 / 100) train loss: 2.300187; val loss: 2.300175
# (Epoch 25 / 100) train loss: 2.300016; val loss: 2.300002
# (Epoch 26 / 100) train loss: 2.299839; val loss: 2.299824
# (Epoch 27 / 100) train loss: 2.299656; val loss: 2.299633
# (Epoch 28 / 100) train loss: 2.299468; val loss: 2.299449
# (Epoch 29 / 100) train loss: 2.299273; val loss: 2.299253
# (Epoch 30 / 100) train loss: 2.299070; val loss: 2.299044
# (Epoch 31 / 100) train loss: 2.298860; val loss: 2.298833
# (Epoch 32 / 100) train loss: 2.298647; val loss: 2.298609
# (Epoch 33 / 100) train loss: 2.298426; val loss: 2.298391
# (Epoch 34 / 100) train loss: 2.298198; val loss: 2.298156
# (Epoch 35 / 100) train loss: 2.297964; val loss: 2.297918
# (Epoch 36 / 100) train loss: 2.297724; val loss: 2.297667
# (Epoch 37 / 100) train loss: 2.297478; val loss: 2.297415
# (Epoch 38 / 100) train loss: 2.297228; val loss: 2.297165
# (Epoch 39 / 100) train loss: 2.296968; val loss: 2.296905
# (Epoch 40 / 100) train loss: 2.296702; val loss: 2.296619
# (Epoch 41 / 100) train loss: 2.296433; val loss: 2.296351
# (Epoch 42 / 100) train loss: 2.296156; val loss: 2.296067
# (Epoch 43 / 100) train loss: 2.295874; val loss: 2.295771
# (Epoch 44 / 100) train loss: 2.295584; val loss: 2.295481
# (Epoch 45 / 100) train loss: 2.295291; val loss: 2.295183
# (Epoch 46 / 100) train loss: 2.294990; val loss: 2.294868
# (Epoch 47 / 100) train loss: 2.294685; val loss: 2.294554
# (Epoch 48 / 100) train loss: 2.294371; val loss: 2.294238
# (Epoch 49 / 100) train loss: 2.294051; val loss: 2.293917
# (Epoch 50 / 100) train loss: 2.293731; val loss: 2.293573
# (Epoch 51 / 100) train loss: 2.293402; val loss: 2.293230
# (Epoch 52 / 100) train loss: 2.293062; val loss: 2.292893
# (Epoch 53 / 100) train loss: 2.292721; val loss: 2.292541
# (Epoch 54 / 100) train loss: 2.292376; val loss: 2.292167
# (Epoch 55 / 100) train loss: 2.292019; val loss: 2.291818
# (Epoch 56 / 100) train loss: 2.291660; val loss: 2.291440
# (Epoch 57 / 100) train loss: 2.291293; val loss: 2.291073
# (Epoch 58 / 100) train loss: 2.290923; val loss: 2.290692
# (Epoch 59 / 100) train loss: 2.290547; val loss: 2.290299
# (Epoch 60 / 100) train loss: 2.290163; val loss: 2.289923
# (Epoch 61 / 100) train loss: 2.289775; val loss: 2.289516
# (Epoch 62 / 100) train loss: 2.289381; val loss: 2.289096
# (Epoch 63 / 100) train loss: 2.288980; val loss: 2.288688
# (Epoch 64 / 100) train loss: 2.288576; val loss: 2.288267
# (Epoch 65 / 100) train loss: 2.288165; val loss: 2.287846
# (Epoch 66 / 100) train loss: 2.287749; val loss: 2.287409
# (Epoch 67 / 100) train loss: 2.287327; val loss: 2.286977
# (Epoch 68 / 100) train loss: 2.286903; val loss: 2.286547
# (Epoch 69 / 100) train loss: 2.286472; val loss: 2.286091
# (Epoch 70 / 100) train loss: 2.286034; val loss: 2.285649
# (Epoch 71 / 100) train loss: 2.285596; val loss: 2.285195
# (Epoch 72 / 100) train loss: 2.285149; val loss: 2.284729
# (Epoch 73 / 100) train loss: 2.284697; val loss: 2.284256
# (Epoch 74 / 100) train loss: 2.284237; val loss: 2.283795
# (Epoch 75 / 100) train loss: 2.283776; val loss: 2.283307
# (Epoch 76 / 100) train loss: 2.283308; val loss: 2.282818
# (Epoch 77 / 100) train loss: 2.282835; val loss: 2.282338
# (Epoch 78 / 100) train loss: 2.282360; val loss: 2.281842
# (Epoch 79 / 100) train loss: 2.281882; val loss: 2.281336
# (Epoch 80 / 100) train loss: 2.281391; val loss: 2.280837
# (Epoch 81 / 100) train loss: 2.280901; val loss: 2.280329
# (Epoch 82 / 100) train loss: 2.280409; val loss: 2.279814
# (Epoch 83 / 100) train loss: 2.279908; val loss: 2.279307
# (Epoch 84 / 100) train loss: 2.279408; val loss: 2.278766
# (Epoch 85 / 100) train loss: 2.278899; val loss: 2.278237
# (Epoch 86 / 100) train loss: 2.278394; val loss: 2.277718
# (Epoch 87 / 100) train loss: 2.277879; val loss: 2.277165
# (Epoch 88 / 100) train loss: 2.277362; val loss: 2.276652
# (Epoch 89 / 100) train loss: 2.276838; val loss: 2.276104
# (Epoch 90 / 100) train loss: 2.276315; val loss: 2.275565
# (Epoch 91 / 100) train loss: 2.275780; val loss: 2.275020
# (Epoch 92 / 100) train loss: 2.275253; val loss: 2.274461
# (Epoch 93 / 100) train loss: 2.274707; val loss: 2.273896
# (Epoch 94 / 100) train loss: 2.274166; val loss: 2.273349
# (Epoch 95 / 100) train loss: 2.273628; val loss: 2.272758
# (Epoch 96 / 100) train loss: 2.273068; val loss: 2.272202
# (Epoch 97 / 100) train loss: 2.272517; val loss: 2.271633
# (Epoch 98 / 100) train loss: 2.271961; val loss: 2.271037
# (Epoch 99 / 100) train loss: 2.271399; val loss: 2.270471
# (Epoch 100 / 100) train loss: 2.270836; val loss: 2.269864
#
# Evaluating Config #3 [of 20]:
#  {'learning_rate': 0.00020538939111434425, 'reg': 0.0003125992529783147, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.LeakyRelu'>, 'optimizer': <class 'exercise_code.networks.optimizer.Adam'>, 'dropout': 0.4, 'hidden_size': 64}
# (Epoch 1 / 100) train loss: 2.231351; val loss: 2.056164
# (Epoch 2 / 100) train loss: 2.010528; val loss: 1.984922
# (Epoch 3 / 100) train loss: 1.871187; val loss: 1.883607
# (Epoch 4 / 100) train loss: 1.729988; val loss: 1.880558
# (Epoch 5 / 100) train loss: 1.623714; val loss: 1.844391
# (Epoch 6 / 100) train loss: 1.514295; val loss: 1.808979
# (Epoch 7 / 100) train loss: 1.415227; val loss: 1.792012
# (Epoch 8 / 100) train loss: 1.318222; val loss: 1.774677
# (Epoch 9 / 100) train loss: 1.213190; val loss: 1.870692
# (Epoch 10 / 100) train loss: 1.116485; val loss: 1.909005
# (Epoch 11 / 100) train loss: 1.025275; val loss: 1.877742
# (Epoch 12 / 100) train loss: 0.940137; val loss: 1.981099
# (Epoch 13 / 100) train loss: 0.845163; val loss: 1.951916
# (Epoch 14 / 100) train loss: 0.769829; val loss: 1.989034
# (Epoch 15 / 100) train loss: 0.679895; val loss: 1.938504
# (Epoch 16 / 100) train loss: 0.607404; val loss: 2.034378
# (Epoch 17 / 100) train loss: 0.548515; val loss: 2.085090
# (Epoch 18 / 100) train loss: 0.482352; val loss: 2.116539
# Stopping early at epoch 17!
#
# Evaluating Config #4 [of 20]:
#  {'learning_rate': 0.0005308446678436537, 'reg': 0.0009766144092082814, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.Relu'>, 'optimizer': <class 'exercise_code.networks.optimizer.sgd_momentum'>, 'dropout': 0.0, 'hidden_size': 512}
# (Epoch 1 / 100) train loss: 2.302138; val loss: 2.296254
# (Epoch 2 / 100) train loss: 2.278930; val loss: 2.233399
# (Epoch 3 / 100) train loss: 2.203762; val loss: 2.107695
# (Epoch 4 / 100) train loss: 2.098442; val loss: 2.033554
# (Epoch 5 / 100) train loss: 1.990712; val loss: 1.945777
# (Epoch 6 / 100) train loss: 1.861122; val loss: 1.918568
# (Epoch 7 / 100) train loss: 1.762091; val loss: 1.866195
# (Epoch 8 / 100) train loss: 1.656971; val loss: 1.917025
# (Epoch 9 / 100) train loss: 1.568415; val loss: 1.840924
# (Epoch 10 / 100) train loss: 1.468854; val loss: 1.921240
# (Epoch 11 / 100) train loss: 1.359460; val loss: 1.872247
# (Epoch 12 / 100) train loss: 1.252786; val loss: 1.876418
# (Epoch 13 / 100) train loss: 1.162671; val loss: 1.953501
# (Epoch 14 / 100) train loss: 1.042593; val loss: 1.927610
# (Epoch 15 / 100) train loss: 0.923905; val loss: 1.986729
# (Epoch 16 / 100) train loss: 0.827816; val loss: 1.929855
# (Epoch 17 / 100) train loss: 0.723984; val loss: 1.956280
# (Epoch 18 / 100) train loss: 0.616235; val loss: 2.010514
# (Epoch 19 / 100) train loss: 0.530125; val loss: 2.146427
# Stopping early at epoch 18!
#
# Evaluating Config #5 [of 20]:
#  {'learning_rate': 7.899984492311143e-06, 'reg': 0.0002854931506434112, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.Relu'>, 'optimizer': <class 'exercise_code.networks.optimizer.Adam'>, 'dropout': 0.1, 'hidden_size': 128}
# (Epoch 1 / 100) train loss: 2.301829; val loss: 2.299875
# (Epoch 2 / 100) train loss: 2.297381; val loss: 2.292526
# (Epoch 3 / 100) train loss: 2.287433; val loss: 2.277910
# (Epoch 4 / 100) train loss: 2.270387; val loss: 2.256606
# (Epoch 5 / 100) train loss: 2.248005; val loss: 2.230417
# (Epoch 6 / 100) train loss: 2.222447; val loss: 2.203289
# (Epoch 7 / 100) train loss: 2.196727; val loss: 2.175751
# (Epoch 8 / 100) train loss: 2.172195; val loss: 2.151376
# (Epoch 9 / 100) train loss: 2.149151; val loss: 2.130012
# (Epoch 10 / 100) train loss: 2.128230; val loss: 2.110933
# (Epoch 11 / 100) train loss: 2.108378; val loss: 2.093678
# (Epoch 12 / 100) train loss: 2.089612; val loss: 2.077376
# (Epoch 13 / 100) train loss: 2.072627; val loss: 2.063227
# (Epoch 14 / 100) train loss: 2.056373; val loss: 2.050771
# (Epoch 15 / 100) train loss: 2.040382; val loss: 2.038719
# (Epoch 16 / 100) train loss: 2.024965; val loss: 2.028417
# (Epoch 17 / 100) train loss: 2.010801; val loss: 2.018426
# (Epoch 18 / 100) train loss: 1.996992; val loss: 2.007726
# (Epoch 19 / 100) train loss: 1.983417; val loss: 2.000141
# (Epoch 20 / 100) train loss: 1.970687; val loss: 1.991220
# (Epoch 21 / 100) train loss: 1.958398; val loss: 1.983751
# (Epoch 22 / 100) train loss: 1.946076; val loss: 1.975687
# (Epoch 23 / 100) train loss: 1.934704; val loss: 1.968867
# (Epoch 24 / 100) train loss: 1.923209; val loss: 1.963095
# (Epoch 25 / 100) train loss: 1.911702; val loss: 1.955456
# (Epoch 26 / 100) train loss: 1.901171; val loss: 1.950995
# (Epoch 27 / 100) train loss: 1.890605; val loss: 1.944751
# (Epoch 28 / 100) train loss: 1.880363; val loss: 1.939125
# (Epoch 29 / 100) train loss: 1.870266; val loss: 1.934387
# (Epoch 30 / 100) train loss: 1.860727; val loss: 1.930260
# (Epoch 31 / 100) train loss: 1.850885; val loss: 1.924551
# (Epoch 32 / 100) train loss: 1.841990; val loss: 1.921078
# (Epoch 33 / 100) train loss: 1.832779; val loss: 1.916242
# (Epoch 34 / 100) train loss: 1.824152; val loss: 1.913341
# (Epoch 35 / 100) train loss: 1.815815; val loss: 1.909211
# (Epoch 36 / 100) train loss: 1.807437; val loss: 1.905628
# (Epoch 37 / 100) train loss: 1.798981; val loss: 1.903515
# (Epoch 38 / 100) train loss: 1.790710; val loss: 1.900456
# (Epoch 39 / 100) train loss: 1.782867; val loss: 1.896983
# (Epoch 40 / 100) train loss: 1.775312; val loss: 1.894994
# (Epoch 41 / 100) train loss: 1.767678; val loss: 1.892346
# (Epoch 42 / 100) train loss: 1.759826; val loss: 1.889513
# (Epoch 43 / 100) train loss: 1.752951; val loss: 1.887577
# (Epoch 44 / 100) train loss: 1.745209; val loss: 1.885033
# (Epoch 45 / 100) train loss: 1.738394; val loss: 1.881725
# (Epoch 46 / 100) train loss: 1.731129; val loss: 1.881032
# (Epoch 47 / 100) train loss: 1.723946; val loss: 1.878103
# (Epoch 48 / 100) train loss: 1.717493; val loss: 1.876782
# (Epoch 49 / 100) train loss: 1.710743; val loss: 1.874803
# (Epoch 50 / 100) train loss: 1.704025; val loss: 1.873576
# (Epoch 51 / 100) train loss: 1.698148; val loss: 1.871181
# (Epoch 52 / 100) train loss: 1.691370; val loss: 1.868748
# (Epoch 53 / 100) train loss: 1.684936; val loss: 1.869210
# (Epoch 54 / 100) train loss: 1.678570; val loss: 1.866124
# (Epoch 55 / 100) train loss: 1.672149; val loss: 1.864943
# (Epoch 56 / 100) train loss: 1.666006; val loss: 1.865203
# (Epoch 57 / 100) train loss: 1.659593; val loss: 1.862535
# (Epoch 58 / 100) train loss: 1.653906; val loss: 1.860942
# (Epoch 59 / 100) train loss: 1.647101; val loss: 1.858886
# (Epoch 60 / 100) train loss: 1.641345; val loss: 1.858635
# (Epoch 61 / 100) train loss: 1.635547; val loss: 1.857171
# (Epoch 62 / 100) train loss: 1.629205; val loss: 1.857046
# (Epoch 63 / 100) train loss: 1.623785; val loss: 1.855525
# (Epoch 64 / 100) train loss: 1.617720; val loss: 1.854332
# (Epoch 65 / 100) train loss: 1.611694; val loss: 1.853511
# (Epoch 66 / 100) train loss: 1.605893; val loss: 1.851660
# (Epoch 67 / 100) train loss: 1.600580; val loss: 1.852520
# (Epoch 68 / 100) train loss: 1.594699; val loss: 1.850653
# (Epoch 69 / 100) train loss: 1.588675; val loss: 1.849795
# (Epoch 70 / 100) train loss: 1.582729; val loss: 1.849188
# (Epoch 71 / 100) train loss: 1.577254; val loss: 1.847946
# (Epoch 72 / 100) train loss: 1.571334; val loss: 1.845747
# (Epoch 73 / 100) train loss: 1.565786; val loss: 1.847215
# (Epoch 74 / 100) train loss: 1.559811; val loss: 1.845171
# (Epoch 75 / 100) train loss: 1.554285; val loss: 1.844545
# (Epoch 76 / 100) train loss: 1.549113; val loss: 1.843511
# (Epoch 77 / 100) train loss: 1.543175; val loss: 1.842933
# (Epoch 78 / 100) train loss: 1.537619; val loss: 1.843775
# (Epoch 79 / 100) train loss: 1.532076; val loss: 1.843149
# (Epoch 80 / 100) train loss: 1.526443; val loss: 1.841069
# (Epoch 81 / 100) train loss: 1.520805; val loss: 1.840580
# (Epoch 82 / 100) train loss: 1.515489; val loss: 1.840493
# (Epoch 83 / 100) train loss: 1.509864; val loss: 1.839994
# (Epoch 84 / 100) train loss: 1.504321; val loss: 1.839075
# (Epoch 85 / 100) train loss: 1.498909; val loss: 1.838397
# (Epoch 86 / 100) train loss: 1.493443; val loss: 1.838681
# (Epoch 87 / 100) train loss: 1.487649; val loss: 1.837760
# (Epoch 88 / 100) train loss: 1.482453; val loss: 1.837021
# (Epoch 89 / 100) train loss: 1.476639; val loss: 1.837221
# (Epoch 90 / 100) train loss: 1.471216; val loss: 1.835842
# (Epoch 91 / 100) train loss: 1.465785; val loss: 1.833920
# (Epoch 92 / 100) train loss: 1.459954; val loss: 1.833252
# (Epoch 93 / 100) train loss: 1.454855; val loss: 1.833688
# (Epoch 94 / 100) train loss: 1.449139; val loss: 1.833757
# (Epoch 95 / 100) train loss: 1.443772; val loss: 1.831363
# (Epoch 96 / 100) train loss: 1.437997; val loss: 1.832651
# (Epoch 97 / 100) train loss: 1.432499; val loss: 1.832666
# (Epoch 98 / 100) train loss: 1.427066; val loss: 1.833677
# (Epoch 99 / 100) train loss: 1.421637; val loss: 1.832094
# (Epoch 100 / 100) train loss: 1.416242; val loss: 1.830292
#
# Evaluating Config #6 [of 20]:
#  {'learning_rate': 9.60082390773419e-07, 'reg': 0.00045588374667534143, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.LeakyRelu'>, 'optimizer': <class 'exercise_code.networks.optimizer.Adam'>, 'dropout': 0.0, 'hidden_size': 128}
# (Epoch 1 / 100) train loss: 2.302695; val loss: 2.302531
# (Epoch 2 / 100) train loss: 2.302380; val loss: 2.302265
# (Epoch 3 / 100) train loss: 2.302067; val loss: 2.301984
# (Epoch 4 / 100) train loss: 2.301723; val loss: 2.301647
# (Epoch 5 / 100) train loss: 2.301335; val loss: 2.301269
# (Epoch 6 / 100) train loss: 2.300902; val loss: 2.300826
# (Epoch 7 / 100) train loss: 2.300406; val loss: 2.300335
# (Epoch 8 / 100) train loss: 2.299851; val loss: 2.299741
# (Epoch 9 / 100) train loss: 2.299220; val loss: 2.299113
# (Epoch 10 / 100) train loss: 2.298521; val loss: 2.298376
# (Epoch 11 / 100) train loss: 2.297749; val loss: 2.297557
# (Epoch 12 / 100) train loss: 2.296893; val loss: 2.296685
# (Epoch 13 / 100) train loss: 2.295961; val loss: 2.295738
# (Epoch 14 / 100) train loss: 2.294958; val loss: 2.294620
# (Epoch 15 / 100) train loss: 2.293868; val loss: 2.293520
# (Epoch 16 / 100) train loss: 2.292695; val loss: 2.292294
# (Epoch 17 / 100) train loss: 2.291447; val loss: 2.290930
# (Epoch 18 / 100) train loss: 2.290104; val loss: 2.289592
# (Epoch 19 / 100) train loss: 2.288708; val loss: 2.288054
# (Epoch 20 / 100) train loss: 2.287209; val loss: 2.286596
# (Epoch 21 / 100) train loss: 2.285660; val loss: 2.284826
# (Epoch 22 / 100) train loss: 2.284015; val loss: 2.283132
# (Epoch 23 / 100) train loss: 2.282301; val loss: 2.281319
# (Epoch 24 / 100) train loss: 2.280529; val loss: 2.279487
# (Epoch 25 / 100) train loss: 2.278694; val loss: 2.277521
# (Epoch 26 / 100) train loss: 2.276789; val loss: 2.275518
# (Epoch 27 / 100) train loss: 2.274858; val loss: 2.273470
# (Epoch 28 / 100) train loss: 2.272850; val loss: 2.271388
# (Epoch 29 / 100) train loss: 2.270800; val loss: 2.269160
# (Epoch 30 / 100) train loss: 2.268729; val loss: 2.266939
# (Epoch 31 / 100) train loss: 2.266570; val loss: 2.264689
# (Epoch 32 / 100) train loss: 2.264422; val loss: 2.262444
# (Epoch 33 / 100) train loss: 2.262222; val loss: 2.260137
# (Epoch 34 / 100) train loss: 2.259986; val loss: 2.257746
# (Epoch 35 / 100) train loss: 2.257725; val loss: 2.255357
# (Epoch 36 / 100) train loss: 2.255446; val loss: 2.252925
# (Epoch 37 / 100) train loss: 2.253146; val loss: 2.250632
# (Epoch 38 / 100) train loss: 2.250855; val loss: 2.248027
# (Epoch 39 / 100) train loss: 2.248507; val loss: 2.245659
# (Epoch 40 / 100) train loss: 2.246145; val loss: 2.243176
# (Epoch 41 / 100) train loss: 2.243828; val loss: 2.240680
# (Epoch 42 / 100) train loss: 2.241435; val loss: 2.238225
# (Epoch 43 / 100) train loss: 2.239058; val loss: 2.235754
# (Epoch 44 / 100) train loss: 2.236696; val loss: 2.233050
# (Epoch 45 / 100) train loss: 2.234284; val loss: 2.230640
# (Epoch 46 / 100) train loss: 2.231896; val loss: 2.228057
# (Epoch 47 / 100) train loss: 2.229524; val loss: 2.225439
# (Epoch 48 / 100) train loss: 2.227118; val loss: 2.222965
# (Epoch 49 / 100) train loss: 2.224736; val loss: 2.220480
# (Epoch 50 / 100) train loss: 2.222357; val loss: 2.217890
# (Epoch 51 / 100) train loss: 2.219981; val loss: 2.215450
# (Epoch 52 / 100) train loss: 2.217611; val loss: 2.212964
# (Epoch 53 / 100) train loss: 2.215260; val loss: 2.210574
# (Epoch 54 / 100) train loss: 2.212934; val loss: 2.208070
# (Epoch 55 / 100) train loss: 2.210606; val loss: 2.205599
# (Epoch 56 / 100) train loss: 2.208248; val loss: 2.203166
# (Epoch 57 / 100) train loss: 2.205925; val loss: 2.200640
# (Epoch 58 / 100) train loss: 2.203656; val loss: 2.198191
# (Epoch 59 / 100) train loss: 2.201371; val loss: 2.195855
# (Epoch 60 / 100) train loss: 2.199096; val loss: 2.193520
# (Epoch 61 / 100) train loss: 2.196819; val loss: 2.191033
# (Epoch 62 / 100) train loss: 2.194561; val loss: 2.188782
# (Epoch 63 / 100) train loss: 2.192336; val loss: 2.186371
# (Epoch 64 / 100) train loss: 2.190078; val loss: 2.184140
# (Epoch 65 / 100) train loss: 2.187911; val loss: 2.181766
# (Epoch 66 / 100) train loss: 2.185684; val loss: 2.179452
# (Epoch 67 / 100) train loss: 2.183494; val loss: 2.177210
# (Epoch 68 / 100) train loss: 2.181343; val loss: 2.174982
# (Epoch 69 / 100) train loss: 2.179179; val loss: 2.172681
# (Epoch 70 / 100) train loss: 2.177025; val loss: 2.170415
# (Epoch 71 / 100) train loss: 2.174894; val loss: 2.168252
# (Epoch 72 / 100) train loss: 2.172775; val loss: 2.166042
# (Epoch 73 / 100) train loss: 2.170664; val loss: 2.164037
# (Epoch 74 / 100) train loss: 2.168593; val loss: 2.161871
# (Epoch 75 / 100) train loss: 2.166508; val loss: 2.159723
# (Epoch 76 / 100) train loss: 2.164412; val loss: 2.157628
# (Epoch 77 / 100) train loss: 2.162396; val loss: 2.155406
# (Epoch 78 / 100) train loss: 2.160348; val loss: 2.153478
# (Epoch 79 / 100) train loss: 2.158353; val loss: 2.151402
# (Epoch 80 / 100) train loss: 2.156305; val loss: 2.149360
# (Epoch 81 / 100) train loss: 2.154324; val loss: 2.147326
# (Epoch 82 / 100) train loss: 2.152329; val loss: 2.145494
# (Epoch 83 / 100) train loss: 2.150357; val loss: 2.143404
# (Epoch 84 / 100) train loss: 2.148407; val loss: 2.141543
# (Epoch 85 / 100) train loss: 2.146453; val loss: 2.139649
# (Epoch 86 / 100) train loss: 2.144522; val loss: 2.137772
# (Epoch 87 / 100) train loss: 2.142592; val loss: 2.135911
# (Epoch 88 / 100) train loss: 2.140653; val loss: 2.133989
# (Epoch 89 / 100) train loss: 2.138788; val loss: 2.132081
# (Epoch 90 / 100) train loss: 2.136853; val loss: 2.130274
# (Epoch 91 / 100) train loss: 2.134959; val loss: 2.128497
# (Epoch 92 / 100) train loss: 2.133100; val loss: 2.126606
# (Epoch 93 / 100) train loss: 2.131286; val loss: 2.124923
# (Epoch 94 / 100) train loss: 2.129427; val loss: 2.123164
# (Epoch 95 / 100) train loss: 2.127604; val loss: 2.121454
# (Epoch 96 / 100) train loss: 2.125752; val loss: 2.119772
# (Epoch 97 / 100) train loss: 2.123950; val loss: 2.118020
# (Epoch 98 / 100) train loss: 2.122168; val loss: 2.116220
# (Epoch 99 / 100) train loss: 2.120392; val loss: 2.114731
# (Epoch 100 / 100) train loss: 2.118596; val loss: 2.113119
#
# Evaluating Config #7 [of 20]:
#  {'learning_rate': 4.4346554702476753e-05, 'reg': 1.1221265374374355e-07, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.Relu'>, 'optimizer': <class 'exercise_code.networks.optimizer.SGD'>, 'dropout': 0.0, 'hidden_size': 64}
# (Epoch 1 / 100) train loss: 2.302587; val loss: 2.302632
# (Epoch 2 / 100) train loss: 2.302573; val loss: 2.302627
# (Epoch 3 / 100) train loss: 2.302559; val loss: 2.302621
# (Epoch 4 / 100) train loss: 2.302545; val loss: 2.302616
# (Epoch 5 / 100) train loss: 2.302531; val loss: 2.302610
# (Epoch 6 / 100) train loss: 2.302517; val loss: 2.302605
# (Epoch 7 / 100) train loss: 2.302503; val loss: 2.302600
# (Epoch 8 / 100) train loss: 2.302488; val loss: 2.302594
# (Epoch 9 / 100) train loss: 2.302474; val loss: 2.302589
# (Epoch 10 / 100) train loss: 2.302460; val loss: 2.302583
# (Epoch 11 / 100) train loss: 2.302446; val loss: 2.302578
# (Epoch 12 / 100) train loss: 2.302432; val loss: 2.302573
# (Epoch 13 / 100) train loss: 2.302418; val loss: 2.302567
# (Epoch 14 / 100) train loss: 2.302403; val loss: 2.302562
# (Epoch 15 / 100) train loss: 2.302389; val loss: 2.302556
# (Epoch 16 / 100) train loss: 2.302375; val loss: 2.302550
# (Epoch 17 / 100) train loss: 2.302361; val loss: 2.302545
# (Epoch 18 / 100) train loss: 2.302347; val loss: 2.302539
# (Epoch 19 / 100) train loss: 2.302332; val loss: 2.302533
# (Epoch 20 / 100) train loss: 2.302317; val loss: 2.302527
# (Epoch 21 / 100) train loss: 2.302304; val loss: 2.302521
# (Epoch 22 / 100) train loss: 2.302288; val loss: 2.302515
# (Epoch 23 / 100) train loss: 2.302274; val loss: 2.302509
# (Epoch 24 / 100) train loss: 2.302259; val loss: 2.302503
# (Epoch 25 / 100) train loss: 2.302245; val loss: 2.302497
# (Epoch 26 / 100) train loss: 2.302230; val loss: 2.302491
# (Epoch 27 / 100) train loss: 2.302215; val loss: 2.302484
# (Epoch 28 / 100) train loss: 2.302201; val loss: 2.302478
# (Epoch 29 / 100) train loss: 2.302186; val loss: 2.302472
# (Epoch 30 / 100) train loss: 2.302172; val loss: 2.302465
# (Epoch 31 / 100) train loss: 2.302157; val loss: 2.302459
# (Epoch 32 / 100) train loss: 2.302142; val loss: 2.302452
# (Epoch 33 / 100) train loss: 2.302127; val loss: 2.302445
# (Epoch 34 / 100) train loss: 2.302111; val loss: 2.302438
# (Epoch 35 / 100) train loss: 2.302097; val loss: 2.302431
# (Epoch 36 / 100) train loss: 2.302082; val loss: 2.302424
# (Epoch 37 / 100) train loss: 2.302066; val loss: 2.302417
# (Epoch 38 / 100) train loss: 2.302051; val loss: 2.302410
# (Epoch 39 / 100) train loss: 2.302035; val loss: 2.302402
# (Epoch 40 / 100) train loss: 2.302020; val loss: 2.302395
# (Epoch 41 / 100) train loss: 2.302004; val loss: 2.302387
# (Epoch 42 / 100) train loss: 2.301989; val loss: 2.302380
# (Epoch 43 / 100) train loss: 2.301973; val loss: 2.302372
# (Epoch 44 / 100) train loss: 2.301957; val loss: 2.302364
# (Epoch 45 / 100) train loss: 2.301941; val loss: 2.302356
# (Epoch 46 / 100) train loss: 2.301924; val loss: 2.302347
# (Epoch 47 / 100) train loss: 2.301908; val loss: 2.302339
# (Epoch 48 / 100) train loss: 2.301892; val loss: 2.302330
# (Epoch 49 / 100) train loss: 2.301875; val loss: 2.302322
# (Epoch 50 / 100) train loss: 2.301859; val loss: 2.302313
# (Epoch 51 / 100) train loss: 2.301841; val loss: 2.302304
# (Epoch 52 / 100) train loss: 2.301824; val loss: 2.302294
# (Epoch 53 / 100) train loss: 2.301807; val loss: 2.302285
# (Epoch 54 / 100) train loss: 2.301790; val loss: 2.302275
# (Epoch 55 / 100) train loss: 2.301772; val loss: 2.302265
# (Epoch 56 / 100) train loss: 2.301755; val loss: 2.302255
# (Epoch 57 / 100) train loss: 2.301737; val loss: 2.302244
# (Epoch 58 / 100) train loss: 2.301719; val loss: 2.302234
# (Epoch 59 / 100) train loss: 2.301700; val loss: 2.302223
# (Epoch 60 / 100) train loss: 2.301682; val loss: 2.302211
# (Epoch 61 / 100) train loss: 2.301663; val loss: 2.302200
# (Epoch 62 / 100) train loss: 2.301644; val loss: 2.302188
# (Epoch 63 / 100) train loss: 2.301625; val loss: 2.302176
# (Epoch 64 / 100) train loss: 2.301606; val loss: 2.302164
# (Epoch 65 / 100) train loss: 2.301586; val loss: 2.302151
# (Epoch 66 / 100) train loss: 2.301566; val loss: 2.302138
# (Epoch 67 / 100) train loss: 2.301547; val loss: 2.302125
# (Epoch 68 / 100) train loss: 2.301526; val loss: 2.302112
# (Epoch 69 / 100) train loss: 2.301506; val loss: 2.302098
# (Epoch 70 / 100) train loss: 2.301485; val loss: 2.302084
# (Epoch 71 / 100) train loss: 2.301464; val loss: 2.302069
# (Epoch 72 / 100) train loss: 2.301443; val loss: 2.302055
# (Epoch 73 / 100) train loss: 2.301422; val loss: 2.302040
# (Epoch 74 / 100) train loss: 2.301400; val loss: 2.302024
# (Epoch 75 / 100) train loss: 2.301378; val loss: 2.302008
# (Epoch 76 / 100) train loss: 2.301355; val loss: 2.301992
# (Epoch 77 / 100) train loss: 2.301333; val loss: 2.301976
# (Epoch 78 / 100) train loss: 2.301310; val loss: 2.301959
# (Epoch 79 / 100) train loss: 2.301286; val loss: 2.301941
# (Epoch 80 / 100) train loss: 2.301263; val loss: 2.301923
# (Epoch 81 / 100) train loss: 2.301239; val loss: 2.301905
# (Epoch 82 / 100) train loss: 2.301214; val loss: 2.301886
# (Epoch 83 / 100) train loss: 2.301190; val loss: 2.301867
# (Epoch 84 / 100) train loss: 2.301165; val loss: 2.301847
# (Epoch 85 / 100) train loss: 2.301139; val loss: 2.301827
# (Epoch 86 / 100) train loss: 2.301114; val loss: 2.301807
# (Epoch 87 / 100) train loss: 2.301087; val loss: 2.301785
# (Epoch 88 / 100) train loss: 2.301061; val loss: 2.301764
# (Epoch 89 / 100) train loss: 2.301034; val loss: 2.301741
# (Epoch 90 / 100) train loss: 2.301006; val loss: 2.301719
# (Epoch 91 / 100) train loss: 2.300978; val loss: 2.301695
# (Epoch 92 / 100) train loss: 2.300950; val loss: 2.301671
# (Epoch 93 / 100) train loss: 2.300921; val loss: 2.301647
# (Epoch 94 / 100) train loss: 2.300891; val loss: 2.301621
# (Epoch 95 / 100) train loss: 2.300861; val loss: 2.301596
# (Epoch 96 / 100) train loss: 2.300831; val loss: 2.301569
# (Epoch 97 / 100) train loss: 2.300800; val loss: 2.301542
# (Epoch 98 / 100) train loss: 2.300768; val loss: 2.301514
# (Epoch 99 / 100) train loss: 2.300736; val loss: 2.301486
# (Epoch 100 / 100) train loss: 2.300704; val loss: 2.301457
#
# Evaluating Config #8 [of 20]:
#  {'learning_rate': 8.858692286409444e-07, 'reg': 8.04584851714879e-07, 'loss_func': <class 'exercise_code.networks.loss.CrossEntropyFromLogits'>, 'num_layer': 2, 'activation': <class 'exercise_code.networks.layer.LeakyRelu'>, 'optimizer': <class 'exercise_code.networks.optimizer.Adam'>, 'dropout': 0.1, 'hidden_size': 512}
# (Epoch 1 / 100) train loss: 2.302234; val loss: 2.301830
# (Epoch 2 / 100) train loss: 2.301178; val loss: 2.300918
# (Epoch 3 / 100) train loss: 2.300097; val loss: 2.299903
# (Epoch 4 / 100) train loss: 2.298926; val loss: 2.298748
# (Epoch 5 / 100) train loss: 2.297637; val loss: 2.297532
# (Epoch 6 / 100) train loss: 2.296203; val loss: 2.296037
# (Epoch 7 / 100) train loss: 2.294581; val loss: 2.294436
# (Epoch 8 / 100) train loss: 2.292810; val loss: 2.292621
# (Epoch 9 / 100) train loss: 2.290857; val loss: 2.290635
# (Epoch 10 / 100) train loss: 2.288693; val loss: 2.288347
# (Epoch 11 / 100) train loss: 2.286319; val loss: 2.286037
# (Epoch 12 / 100) train loss: 2.283790; val loss: 2.283422
# (Epoch 13 / 100) train loss: 2.281024; val loss: 2.280611
# (Epoch 14 / 100) train loss: 2.278087; val loss: 2.277722
# (Epoch 15 / 100) train loss: 2.274967; val loss: 2.274370
# (Epoch 16 / 100) train loss: 2.271673; val loss: 2.270924
# (Epoch 17 / 100) train loss: 2.268161; val loss: 2.267341
# (Epoch 18 / 100) train loss: 2.264508; val loss: 2.263755
# (Epoch 19 / 100) train loss: 2.260746; val loss: 2.260074
# (Epoch 20 / 100) train loss: 2.256888; val loss: 2.255944
# (Epoch 21 / 100) train loss: 2.252858; val loss: 2.252007
# (Epoch 22 / 100) train loss: 2.248732; val loss: 2.247576
# (Epoch 23 / 100) train loss: 2.244532; val loss: 2.243369
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 6
#       2 from exercise_code.networks import optimizer
#       4 model_type = ClassificationNet
# ----> 6 best_model, best_config, results  = random_search(
#       7     dataloaders['train_small'], dataloaders['val_500files'],
#       8     random_search_spaces = {
#       9         "learning_rate": ([1e-3, 1e-7], 'log'),
#      10         "reg": ([1e-3, 1e-7], "log"),
#      11         "loss_func": ([CrossEntropyFromLogits], "item"),
#      12         "num_layer": ([2], "int"),
#      13         "activation": ([Relu, LeakyRelu], "item"),
#      14         "optimizer": ([optimizer.Adam, optimizer.sgd_momentum, optimizer.SGD], "item"),
#      15         "dropout": ([0.0, 0.1, 0.4], "item"),
#      16         "hidden_size": ([64, 128, 256, 512], "item")
#      17     },
#      18     model_class=model_type,
#      19     num_search = 20, patience=10, epochs= 100)
#      21 #model.save_model('./models/best_model')
#      22
#      23 ########################################################################
#    (...)
#      32 # will result in an unknown behavior.                                  #
#      33 ########################################################################
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/hyperparameter_tuning.py:86, in random_search(train_loader, val_loader, random_search_spaces, model_class, num_search, epochs, patience)
#      83 for _ in range(num_search):
#      84     configs.append(random_search_spaces_to_config(random_search_spaces))
# ---> 86 return findBestConfig(train_loader, val_loader, configs, epochs, patience,
#      87                       model_class)
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/hyperparameter_tuning.py:109, in findBestConfig(train_loader, val_loader, configs, EPOCHS, PATIENCE, model_class)
#     107 model = model_class(**configs[i])
#     108 solver = Solver(model, train_loader, val_loader, **configs[i])
# --> 109 solver.train(epochs=EPOCHS, patience=PATIENCE)
#     110 results.append(solver.best_model_stats)
#     112 if not best_val or solver.best_model_stats["val_loss"] < best_val:
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/solver.py:144, in Solver.train(self, epochs, patience)
#     142 # Update the model parameters.
#     143 validate = False
# --> 144 train_loss = self._step(X, y, validation=validate)
#     146 self.train_batch_loss.append(train_loss)
#     147 train_epoch_loss += train_loss
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/solver.py:119, in Solver._step(self, X, y, validation)
#     117 self.opt.backward(y_pred, y)
#     118 # Update weights
# --> 119 self.opt.step()
#     120 # If it was a training step, we need to count operations for
#     121 # backpropagation as well
#     122 self.num_operation += self.model.num_operation
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/networks/optimizer.py:238, in Adam.step(self)
#     235 config = self.optim_configs[name]
#     237 # Update the parameter
# --> 238 w_updated, config = self._update(w, dw, config, lr=self.lr)
#     239 self.model.params[name] = w_updated
#     240 self.optim_configs[name] = config
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/networks/optimizer.py:213, in Adam._update(self, w, dw, config, lr)
#     211 v = beta2 * v + (1 - beta2) * (dw ** 2)
#     212 v_hat = v / (1 - np.power(beta2, t + 1))
# --> 213 next_w = w - learning_rate * m_hat / (np.sqrt(v_hat) + eps)
#     215 config['t'] = t + 1
#     216 config['m'] = m
#
# KeyboardInterrupt:

# %%
my_config = {
    "learning_rate": 0.0001, "reg": 0.001, "loss_func": CrossEntropyFromLogits, "num_layer": 2, "activation": Relu, "optimizer": optimizer.Adam,  "dropout": 0.5, "hidden_size": 512
}

model_args = { "learning_rate": my_config["learning_rate"], "reg": my_config["reg"], "loss_func" : my_config["loss_func"],
    "num_layer":  my_config["num_layer"],  "activation": my_config["activation"], "optimizer": my_config["optimizer"],
    "hidden_size": my_config["hidden_size"], "dropout":    my_config["dropout"],
}

# %%
best_model = ClassificationNet(**model_args)

# %%
solver = Solver(
    best_model,
    dataloaders['train'],
    dataloaders['val'],
    loss_func = my_config['loss_func'], 
    learning_rate = my_config['learning_rate'],
    optimizer = my_config['optimizer'],
    verbose      = True,     
    print_every  = 1,  
)

solver.train(epochs=300, patience=10)
# Out:
# (Epoch 1 / 300) train loss: 2.012472; val loss: 1.838473
# (Epoch 2 / 300) train loss: 1.760666; val loss: 1.727252
# (Epoch 3 / 300) train loss: 1.667857; val loss: 1.666529
# (Epoch 4 / 300) train loss: 1.606573; val loss: 1.624148
# (Epoch 5 / 300) train loss: 1.560687; val loss: 1.603599
# (Epoch 6 / 300) train loss: 1.523902; val loss: 1.580300
# (Epoch 7 / 300) train loss: 1.493273; val loss: 1.564769
# (Epoch 8 / 300) train loss: 1.464259; val loss: 1.547996
# (Epoch 9 / 300) train loss: 1.437296; val loss: 1.541281
# (Epoch 10 / 300) train loss: 1.412808; val loss: 1.530945
# (Epoch 11 / 300) train loss: 1.389424; val loss: 1.513184
# (Epoch 12 / 300) train loss: 1.367789; val loss: 1.510838
# (Epoch 13 / 300) train loss: 1.345982; val loss: 1.511338
# (Epoch 14 / 300) train loss: 1.326833; val loss: 1.499856
# (Epoch 15 / 300) train loss: 1.308783; val loss: 1.502685
# (Epoch 16 / 300) train loss: 1.289779; val loss: 1.495833
# (Epoch 17 / 300) train loss: 1.273149; val loss: 1.491959
# (Epoch 18 / 300) train loss: 1.254055; val loss: 1.495920
# (Epoch 19 / 300) train loss: 1.238679; val loss: 1.490184
# (Epoch 20 / 300) train loss: 1.224106; val loss: 1.488409
# (Epoch 21 / 300) train loss: 1.209009; val loss: 1.490628
# (Epoch 22 / 300) train loss: 1.192303; val loss: 1.490549
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[139], line 12
#       1 solver = Solver(
#       2     best_model,
#       3     dataloaders['train'],
#    (...)
#       9     print_every  = 1,
#      10 )
# ---> 12 solver.train(epochs=300, patience=10)
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/solver.py:137, in Solver.train(self, epochs, patience)
#     132 for t in range(epochs):
#     133
#     134     # Iterate over all training samples
#     135     train_epoch_loss = 0.0
# --> 137     for batch in self.train_dataloader:
#     138         # Unpack data
#     139         X = batch['image']
#     140         y = batch['label']
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/data/dataloader.py:57, in DataLoader.__iter__(self)
#      55 batch = []
#      56 for index in index_iterator:
# ---> 57     batch.append(self.dataset[index])
#      58     if len(batch) == self.batch_size:
#      59         yield batch_to_numpy(combine_batch_dicts(batch))
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/data/image_folder_dataset.py:129, in ImageFolderDataset.__getitem__(self, index)
#     127 image = self.load_image_as_numpy(path)
#     128 if self.transform is not None:
# --> 129     image = self.transform(image)
#     130 data_dict = {
#     131     "image": image,
#     132     "label": label,
#     133 }
#     135 return data_dict
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/data/image_folder_dataset.py:255, in ComposeTransform.__call__(self, images)
#     253 def __call__(self, images):
#     254     for transform in self.transforms:
# --> 255         images = transform(images)
#     256     return images
#
# KeyboardInterrupt:

# %%
print("Training accuracy: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuracy: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuracy: 0.72200
# Validation accuracy: 0.51382

# %%
best_model.save_model('./models/best_model.p')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 best_model.save_model('./models/best_model.p')
#
# TypeError: ClassificationNet.save_model() takes 1 positional argument but 2 were given

# %% [markdown]
# Now it's time to edit the ranges above and adjust them to explore regions that performed well!
#
# Also, feel free to experiment around. Other hyperparameters you can change are the network architecture, optimizer, activations functions and many more.
#
# Try to get an accuracy as high as possible, since that's all what counts for this submission!
#
# You'll pass if you reach at least **48%** accuracy on our test set - but there will also be a leaderboard of all students of this course. Can you make it to the top?

# %% [markdown]
# ## 3.5 Checking the validation accuracy

# %%
from exercise_code.tests.base_tests import bcolors

labels, pred, acc = best_model.get_dataset_prediction(dataloaders['train'])
res = bcolors.colorize("green", acc * 100) if acc * 100 > 48 else bcolors.colorize("red", acc * 100)
print("Train Accuracy: {}%".format(res))
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['val'])
res = bcolors.colorize("green", acc * 100) if acc * 100 > 48 else bcolors.colorize("red", acc * 100)
print("Validation Accuracy: {}%".format(res))
# Out:
# Train Accuracy: 68.44284188034187%
# Validation Accuracy: 51.35216346153846%

# %% [markdown]
# # 4. Test your model
# When you have finished the hyperparameter tuning and you found your final model which performs well on the validation set (**you should at least get 48% accuracy on the validation set!**), it's time to run your model on the test set.
#
# <div class="alert alert-danger">
#     <h3>Important</h3>
#     <p>As you have learned in the lecture, you must only use the test set once! So only run the next cell if you are completely sure that your model works well enough and that you are ready to submit. Your test set is different from the test set on our server, so results may vary a bit. Nevertheless, you will get a reasonable approximation of your model's performance if you perform the final evaluation on the test set only once.</p>
#     <p>If you are an external student that can't use our submission webpage: this test performance is your final result and if you surpassed the threshold, you have completed this exercise :). Now, train again to aim for a better number!</p>
# </div>

# %%
# comment this part out to see your model's performance on the test set.
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['test'])
res = bcolors.colorize("green", acc * 100) if acc * 100 > 48 else bcolors.colorize("red", acc * 100)
print("Test Accuracy: {}%".format(res))
# Out:
# Test Accuracy: 51.462339743589745%

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>The "real" test set is actually the dataset we're using for testing your model, which is <b>different</b> from the test-set you're using here.</p>
# </div>

# %% [markdown]
# # 5. Saving your Model

# %%
from exercise_code.networks import MyOwnNetwork, ClassificationNet

# %%
#if this cell results in an error, please try restarting your kernel and rerunning the whole notebook.
from exercise_code.tests import save_pickle
best_model.eval()
save_pickle({"cifar_fcn": best_model}, "cifar_fcn.p")
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[121], line 4
#       2 from exercise_code.tests import save_pickle
#       3 best_model.eval()
# ----> 4 save_pickle({"cifar_fcn": best_model}, "cifar_fcn.p")
#
# File ~/Documents/python/i2dl/exercise_06/exercise_code/tests/eval_utils.py:22, in save_pickle(data_dict, file_name)
#      20 if not os.path.exists(directory):
#      21     os.makedirs(directory)
# ---> 22 pickle.dump(data_dict, open(os.path.join(directory, file_name), 'wb', 4))
#
# PicklingError: Can't pickle <class 'exercise_code.networks.layer.Relu'>: it's not the same object as exercise_code.networks.layer.Relu

# %%
from exercise_code.submit import submit_exercise

submit_exercise('../output/exercise_06')

# %% [markdown]
# # 6. Submission Instructions
#
# Congratulations! You've just built your first image classifier! To complete the exercise, submit your final model to our submission portal - you probably know the procedure by now.
#
# 1. Go on [our submission page](https://i2dl.vc.in.tum.de/), register for an account and login. We use your matriculation number and send you an email with the login details to the associated mail account. When in doubt, login into tum-online and check your mails there. You will get an id which we'll need in the next step.
# 2. Log into [our submission page](https://i2dl.vc.in.tum.de/), with your account details and upload the zip file.
# 3. Your submission will be evaluated by our system and you will get feedback about the performance of it. You will get an email with your score, as well as a message if you have surpassed the threshold or not.
# 4. Within the working period, you can submit as many solutions as you want to get the best possible score.
#
#
# # 7. Submission Goals
#
# - Goal: Successfully implement a fully connected NN image classifier and tune the hyperparameters.
#
# - Passing Criteria: This time, there are no unit tests checking specific components of your code. To  pass the submission your model needs to reach at least **48% accuracy** on __our__ test dataset. The submission system will show you a number between 0 and 100 which corresponds to your accuracy.
#
# - You can make **$\infty$** submissions until the deadline. Your __best submission__ will be considered for the bonus.
